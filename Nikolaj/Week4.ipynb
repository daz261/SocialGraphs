# %% [markdown]
# # Overview
#
# This week is all about working with data. I'm not going to lie to you. This part might be frustrating - but frustration is an integral part of learning. Real data is almost always messy & difficult ... and learning to deal with that fact, is a key part of being a data scientist.
#
# Enough about the process, let's get to the content! Welcome to ... (drumroll drumroll drumroll)

# %% [markdown]
# # <center> The Legend of Zelda: Breath of the Wild </center>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("zw47_q9wbBE",width=800, height=450)

# %% [markdown]
# Today, we will use network science and the [Zelda Wiki](https://zelda.fandom.com/wiki/Main_Page) to learn about the relationships of BotW characters.
#
# To create the network, we will download the Zelda Wiki pages for all characters in BotW (enemies and bosses included). Next, we will create the network of the pages that link to each other. Since wiki pages not only link to [Link](https://zelda.fandom.com/wiki/Link) but also to each other (Anna: "yes.. I know.. bad joke -- but come on our hero's name is Link!!!! I can't help myself"). So [Link](https://zelda.fandom.com/wiki/Link) links to  [Princess Zelda](https://zelda.fandom.com/wiki/Princess_Zelda) and viceversa, for example.
#
# Next time, we'll use our network skills (as well as new ones) to understand that network. Further down the line, we'll use natural language processing to understand the text displayed on those pages.
#
# But for today, the tasks are:
#
# * Learn about regular expressions
# * Learn about Pandas dataframes
# * Download and store (for later use) all characters and their pages from the Zelda Wiki
# * Extract all the internal wiki-links that connect the characters on the Zelda Wiki
# * Generate the network of characters from the Zelda Wiki.
# * Calculate some simple network statistics.

# %% [markdown]
# ---
#
# # Prelude part 1: Regular expressions
#
# Before we get started, we have to get a little head start on the _Natural Language Processing_ part of the class. This is a new direction for us, up to now, we've mostly been doing math-y stuff with Python, but today, we're going to be using Python to work through a text. The central thing we need to be able to do today, is to extract internal wiki links. And for that we need regular expressions.
#
# > _Exercises_: Regular expressions round 1\.
# >
# > * Read [**this tutorial**](https://developers.google.com/edu/python/regular-expressions) to form an overview of regular expressions. This is important to understand the content of the tutorial (also very useful later), so you may actually want to work through the examples.
# > * Now, explain in your own words: what are regular expressions?
# > * Provide an example of a regex to match 4 digits numbers (by this, I mean precisely 4 digits, you should not match any part of numbers with e.g. 5 digits). In your notebook, use `findall` to show that your regex works on this [test-text](https://raw.githubusercontent.com/SocialComplexityLab/socialgraphs2021/main/files/regex_exercise.txt). **Hint**: a great place to test out regular expressions is: https://regex101.com.
# > * Provide an example of a regex to match words starting with "super". Show that it works on the [test-text](https://raw.githubusercontent.com/SocialComplexityLab/socialgraphs2021/main/files/regex_exercise.txt).
# >

# %%
def checkmatch(match):
    if match:
        print("match: ",match.group())
    else:
        print("no match")

# %%
# regular expressions is a library/language for matching and finding text patterns in strings.

# part 3.1
import regex as re
str = "123456"
match = re.search(r'1234',str)
checkmatch(match)
# part 3.2
import requests
link = "https://raw.githubusercontent.com/SocialComplexityLab/socialgraphs2021/main/files/regex_exercise.txt"
f2 = requests.get(link)
#print(f2.text)

match2 = re.findall(r'fanny pack',f2.text)
for m in match2:
    print(m)
# part 4
match3 = re.findall(f'super\w+',f2.text)
for m in match3:
    print(m)
# Out:
# match:  1234
# fanny pack
# fanny pack
# fanny pack
# fanny pack
# superpolaroid
# supertaxidermy
# superbeer

# %% [markdown]
# Finally, we need to figure out how to match internal Zelda wiki links. Zelda wiki links come in different [flavors](https://zelda.fandom.com/wiki/Guidelines:Getting_Started). First, let's focus on those linking to pages directly (this step will help us collecting the list of characters).
#
# Direct links are always enclosed in double square brackets, e.g. `[[name of character]]`, or double curly brackets, `{{Term|Series|name of character|link}}` and occur like this:
#
#     ... some text [[Princess Zelda]] some more text ...
#     ... some text {{Term|BotW|Princess Zelda|link}} some more text ...
#
# both linking to the page [`https://zelda.fandom.com/wiki/Princess_Zelda`](https://zelda.fandom.com/wiki/Princess_Zelda).
#
# The second type of link uses text that is different from the page name, here's an example:
#
#     ... some text [[Princess Zelda|Zelda]] some more text ...
#     ... some text {{Term|BotW|Princess Zelda|link|display=Zelda}} some more text ...
#
# both still linking to the page [`https://zelda.fandom.com/wiki/Princess_Zelda`](https://zelda.fandom.com/wiki/Princess_Zelda). Note that there are many series of The Legend of Zelda, but, because we are going to focus on Breath of the Wild (BotW) and to make our data collection a little bit easier, we will **not look for direct links to other series** even if characters can be recurrent (i.e. we will look for links in double curly brackets always in the form `{{Term|BotW|name of character|link}}`).

# %% [markdown]
# Now it's your turn.
#
# > _Exercise_: Regular expressions round 2\. Show that you can extract the direct Zelda wiki links from the [Zelda test-text](https://raw.githubusercontent.com/SocialComplexityLab/socialgraphs2021/main/files/Zelda_regex_exercise.txt). Perhaps you can find inspiration on stack overflow or similar. **Hint**: Try to solve this exercise on your own (that's what you will get the most out of - learning wise), but if you get stuck ... you will find the solution in one of the video lectures below.
# >

# %%
# Extract direct zelda wiki links
link = "https://raw.githubusercontent.com/SocialComplexityLab/socialgraphs2021/main/files/Zelda_regex_exercise.txt"
f3 = requests.get(link)
print(f3.text)
match = re.findall(r'\{\{Term\|BotW\|.*?\}\}',f3.text)
# Out:
# Zelda is not only the princess of Hyrule, she is also an aspiring scholar who is very curious. She is also the leader of the [[Champion]]s of Hyrule. Zelda is the mysterious voice that guides {{Term|BotW|Link|link}} throughout his journey while she contains Calamity Ganon inside of Hyrule Castle. Zelda has been training to unlock her sealing powers passed down the royal family since she was 7 years old, one year after her mother unexpectedly passed away. With her mother gone there was nobody else around with the sacred power who could teach her how to use it, leaving Zelda to figure it out on her own. 100 years prior to the events of BotW, Zelda met with the Champions. After meeting with them, she left the Castle to research ancient technology, but she did not come across anything of note. During this time, she felt the presence of {{Term|BotW|Calamity Ganon|link|display=Ganon}} and devoted herself to learning all she could about ancient relics in order to stop him. She then met with a fortune teller who told her a prophecy, to which Zelda felt that there was not much time left. The following day, Link was appointed as Zelda\'s knight, to Zelda\'s chagrin. During the ceremony, [[Urbosa]] explains that Link is a living reminder of Zelda\'s own failures. Link and Zelda then set out to [[Goron City]] to make adjustments to the {{Term|BotW|Divine Beast Vah Rudania|link}} to make it easier for [[Daruk]] to control. During their journey to [[Eldin (Region)|Eldin]], Zelda comes to a stop and asks him how proficient he is wielding his [[Master Sword|Sword]] and asks him if he can hear the voice within the blade.

# %% [markdown]
# # Prelude part 2: Pandas DataFrames

# %% [markdown]
# Before starting, we will also learn a bit about [pandas dataframes](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html), a very user-friendly data structure that you can use to manipulate tabular data. Pandas dataframes are implemented within the [pandas package](https://pandas.pydata.org/).
#
# Pandas dataframes should be intuitive to use. **We suggest you to go through the [10 minutes to Pandas tutorial](https://pandas.pydata.org/pandas-docs/version/0.22/10min.html#min) to learn what you need to solve the next exercise.**

# %% [markdown]
# ---
#
# # Part A: Download the Zelda Wikipages of characters

# %% [markdown]
# It's time to download all of the pages of the characters. Use your experience with APIs from Week 1\. To get started, I **strongly** recommend that you re-watch the **APIs video lecture** from that week - it contains lots of useful tips on this specific activity (yes, we had planned this all along!). I've included it below for your covenience.

# %%
YouTubeVideo("9l5zOfh0CRo",width=800, height=450)

# %% [markdown]
# Now, to download the Zelda wiki pages of characters, we first need to collect the list of all characters in BotW, starting from the following pages:
#
# 1. [The list of allies](https://zelda.fandom.com/wiki/Characters_in_Breath_of_the_Wild)
# 2. [The list of enemies](https://zelda.fandom.com/wiki/Enemies_in_Breath_of_the_Wild)
# 3. [The list of bosses](https://zelda.fandom.com/wiki/Bosses_in_Breath_of_the_Wild)

# %% [markdown]
# >
# >  _Exercise 1_: Collect the list of BotW Characters
# >
# > If you open any of the pages above, you will quickly see that characters are divided by their location in the game (allies) or type (enemies and bosses) and organized alphabetically, but, most importantly, their names are displayed in the form of links to their page. This means that if we use regular expressions to detect all links in the page description we will find them all! Let's get started:
# > 1. for each page above, find the baseurl and title and build the related API query (add the parameter `rvslots=*` to your query's content)
# > 2. use the query to collect the page (you can save it in a json file for future use) and extract its content
# > 3. build a regular expression to find all characters' names (**hint**: all links in these pages have the same format, i.e. `{{Term|Series|name of character|link}}`)
# > 4. add the characters names and their role (i.e. "Ally", "Enemy", and "Boss") in a Pandas DataFrame. How many unique characters did you find? How many of them are allies, enemies, and bosses? Are there any repeated characters? If so, drop the duplicates, then save the data in a csv file
# >
# > **Note**:
# > 1. In the Enemies page there is a section called "Traps", we do not want to include this list in our dataset
# > 2. Some Bosses have a link in *parenthesis* to their location in the game, you should filter these links out

# %%
# Ex 1.1
import urllib.request

urla = 'https://zelda.fandom.com/wiki/Characters_in_Breath_of_the_Wild'
urle = 'https://zelda.fandom.com/wiki/Enemies_in_Breath_of_the_Wild'
urlb = 'https://zelda.fandom.com/wiki/Bosses_in_Breath_of_the_Wild'


response = urllib.request.urlopen(urla)
data = response.read()      # a `bytes` object
text = data.decode('utf-8')
text


baseurl = "https://zelda.fandom.com/api.php?"
action = "action=query"
title_a = "titles=Characters_in_Breath_of_the_Wild"
title_e = "titles=Enemies_in_Breath_of_the_Wild"
title_b = "titles=Bosses_in_Breath_of_the_Wild"
content = "prop=revisions&rvprop=content&rvslots=*"
dataformat ="format=json"

query_a = "{}{}&{}&{}&{}".format(baseurl, action, content, title_a, dataformat)
query_e = "{}{}&{}&{}&{}".format(baseurl, action, content, title_e, dataformat)
query_b = "{}{}&{}&{}&{}".format(baseurl, action, content, title_b, dataformat)


print(query_a)
print(query_e)
print(query_b)
# Out:
# https://zelda.fandom.com/api.php?action=query&prop=revisions&rvprop=content&rvslots=*&titles=Characters_in_Breath_of_the_Wild&format=json
# https://zelda.fandom.com/api.php?action=query&prop=revisions&rvprop=content&rvslots=*&titles=Enemies_in_Breath_of_the_Wild&format=json
# https://zelda.fandom.com/api.php?action=query&prop=revisions&rvprop=content&rvslots=*&titles=Bosses_in_Breath_of_the_Wild&format=json

# %%
# Ex 1.2 #
import json

wikiresponse = urllib.request.urlopen(query_a)
wikidata = wikiresponse.read()
wikitext_a = wikidata.decode('utf-8')
json_a = json.loads(wikitext_a)
#print(json_a)
#a_text = crap(json_a,77604)
a_text = json_a['query']['pages']['77604']['revisions'][0]['slots']['main']['*']
#print(a_text)
wikiresponse = urllib.request.urlopen(query_e)
wikidata = wikiresponse.read()
wikitext_e = wikidata.decode('utf-8')
json_e = json.loads(wikitext_e)
#e_text = crap(json_e,77608)
e_text = json_e['query']['pages']['77608']['revisions'][0]['slots']['main']['*']
# Take out everything after the ememies section of the webpage, i.e. Traps
e_filter = e_text.split('==Traps==')[0]

wikiresponse = urllib.request.urlopen(query_b)
wikidata = wikiresponse.read()
wikitext_b = wikidata.decode('utf-8')
json_b = json.loads(wikitext_b)
#print(json_b)
b_text = json_b['query']['pages']['77607']['revisions'][0]['slots']['main']['*']
print(b_text)

#print(e_filter)
# Out:
# <noinclude>{{DISPLAYTITLE: Bosses in {{BotW|-}}}}
# The following is a list of [[Boss]]es from {{BotW}}.</noinclude>
#
# ==Overworld Bosses==
# <gallery class="center">
# File:BotW Stone Talus Model.png|{{Term|BotW|Stone Talus|link}}
# File:BotW Stone Talus (Junior) Fight.jpg|{{Term|BotW|Stone Talus (Junior)|link}}<br>{{Small|''({{Term|BotW|Dueling Peaks South|link}})''}}
# File:BotW Stone Talus (Senior) Fight.jpg|{{Term|BotW|Stone Talus (Senior)|link}}<br>{{Small|''({{Term|BotW|North Dueling Peaks|link}})''}}
# File:BotW Stone Talus (Luminous) Model.png|{{Term|BotW|Stone Talus (Luminous)|link}}
# File:BotW Stone Talus (Rare) Model.png|{{Term|BotW|Stone Talus (Rare)|link}}
# File:BotW Igneo Talus Model.png|{{Term|BotW|Igneo Talus|link}}
# File:BotW Frost Talus Model.png|{{Term|BotW|Frost Talus|link}}
# File:BotW Hinox Model.png|{{Term|BotW|Hinox|link}}
# File:BotW Hinox Model 2.jpg|{{Term|BotW|Hinox|link}} (Youngest Kin)<br>{{Small|''({{Term|BotW|Mount Taran|link}})''}}
# File:BotW Hinox (Middle Kin) Model.png|{{Term|BotW|Hinox|link}} (Middle Kin)<br>{{Small|''({{Term|BotW|Mount Taran|link}})''}}
# File:BotW Hinox (Oldest Kin) Model.png|{{Term|BotW|Hinox|link}} (Oldest Kin)<br>{{Small|''({{Term|BotW|Mount Taran|link}})''}}
# File:BotW Blue Hinox Model.png|{{Term|BotW|Blue Hinox|link}}
# File:BotW Black Hinox Model.png|{{Term|BotW|Black Hinox|link}}
# File:BotW Stalnox Model.png|{{Term|BotW|Stalnox|link}}
# File:BotW Molduga Model.png|{{Term|BotW|Molduga|link}}
# File:BotW Igneo Talus Titan Model.png|{{Term|BotW|Igneo Talus Titan|link}} {{DLC|TCB}}<br>{{Small|''({{Term|BotW|Lake Darman|link}})''}}
# File:BotW Molduking Model.png|{{Term|BotW|Molduking|link}} {{DLC|TCB}}<br>{{Small|''({{Term|BotW|Gerudo Desert|link}})''}}
# </gallery>
#
# ==Dungeon Bosses==
# <gallery class="center">
# File:BotW Windblight Ganon Model.png|''Scourge of Divine Beast Vah Medoh''<br>{{Term|BotW|Windblight Ganon|link}}<br>{{Small|''({{Term|BotW|Divine Beast Vah Medoh|link}})''}}<br>{{Small|''({{Term|BotW|Illusory Realm|link}})''}}
# File:BotW Fireblight Ganon Model.png|''Scourge of Divine Beast Vah Rudania''<br>{{Term|BotW|Fireblight Ganon|link}}<br>{{Small|''({{Term|BotW|Divine Beast Vah Rudania|link}})''}}<br>{{Small|''({{Term|BotW|Illusory Realm|link}})''}}
# File:BotW Thunderblight Ganon Model.png|''Scourge of Divine Beast Vah Naboris''<br>{{Term|BotW|Thunderblight Ganon|link}}<br>{{Small|''({{Term|BotW|Divine Beast Vah Naboris|link}})''}}<br>{{Small|''({{Term|BotW|Illusory Realm|link}})''}}
# File:BotW Waterblight Ganon Model.png|''Scourge of Divine Beast Vah Ruta''<br>{{Term|BotW|Waterblight Ganon|link}}<br>{{Small|''({{Term|BotW|Divine Beast Vah Ruta|link}})''}}<br>{{Small|''({{Term|BotW|Illusory Realm|link}})''}}
# File:BotW Master Kohga Model.png|''Leader of the Yiga Clan''<br>{{Term|BotW|Master Kohga|link}}<br>''{{Small|({{Term|BotW|Yiga Clan Hideout|link}})''}}
# File:BotW Monk Maz Koshia Model.png|''The Divine Trial''<br>{{Term|BotW|Monk Maz Koshia|link}} {{DLC|TCB}}<br>{{Small|''({{Term|BotW|Final Trial|link}})''}}
# File:BotW Calamity Ganon Model.png||''Scourge of Hyrule Castle''<br>{{Term|BotW|Calamity Ganon|link}}<br>{{Small|''({{Term|BotW|Hyrule Castle (Breath of the Wild)|link}})''}}
# File:BotW Dark Beast Ganon Model.png||''Hatred and Malice Incarnate''<br>{{Term|BotW|Dark Beast Ganon|link}}<br>{{Small|''({{Term|BotW|Central Hyrule|link}})''}}
# </gallery>
#
# <noinclude>{{Template:BossNav}}[[Category:Boss Galleries]]</noinclude>
# [[fr:Boss_et_Mini-Boss_dans_Breath_of_the_Wild]]
# [[zh-tw:《曠野之息》的首領]]

# %%
# function that removes the term '|link' from the end of a list of matchings
def removelink(match):
    import regex as re
    list = []
    for m in match:
        tempmatch = re.search(r'\|link',m)
        if tempmatch:
            list.append(m[0:-5])
    return list

# %%
# Ex 1.3
import numpy as np

match_a = re.findall(r'\{\{Term\|BotW\|(.*?)\}\}',a_text)
match_e = re.findall(r'\{\{Term\|BotW\|(.*?)\}\}',e_filter)
# The part "[^(]" removes the links to locations that some of the bosses have
match_b = re.findall(r'[^(]\{\{Term\|BotW\|(.*?)\}\}',b_text)

#for m in match_b:
#    print(m)
#print("\n")

allies = removelink(match_a)
print(f'number of allies (before duplicates removed): {len(allies)}')
enemies = removelink(match_e)
print(f'number of enemies (before duplicates removed): {len(enemies)}')
bosses = removelink(match_b)
print(f'number of bosses (before duplicates removed): {len(bosses)}')

# Remove duplicates names from the lists of characters
allies = np.unique(np.array(allies))
fakeallies = [np.where(allies == 'Master Kohga')[0][0],np.where(allies == 'Calamity Ganon')[0][0]]
allies = np.delete(allies,fakeallies)
enemies = np.unique(np.array(enemies))
bosses = np.unique(np.array(bosses))
#print(f'\n{allies}')
print(f'\n{bosses}')

print(f'\nnumber of allies (after duplicates removed): {len(allies)}')
print(f'number of enemies (after duplicates removed): {len(enemies)}')
print(f'number of bosses (after duplicates removed): {len(bosses)}')

#NIKOLAJ: You have 2 too many allies because 2 of them are also bosses.
# You also need to remove the "bosses" that have parenthesis around them, i.e. ({{...}}), because they are links to other stuff (places I think)
# Out:
# number of allies (before duplicates removed): 573
# number of enemies (before duplicates removed): 71
# number of bosses (before duplicates removed): 25
#
# ['Black Hinox' 'Blue Hinox' 'Calamity Ganon' 'Dark Beast Ganon'
#  'Fireblight Ganon' 'Frost Talus' 'Hinox' 'Igneo Talus'
#  'Igneo Talus Titan' 'Master Kohga' 'Molduga' 'Molduking'
#  'Monk Maz Koshia' 'Stalnox' 'Stone Talus' 'Stone Talus (Junior)'
#  'Stone Talus (Luminous)' 'Stone Talus (Rare)' 'Stone Talus (Senior)'
#  'Thunderblight Ganon' 'Waterblight Ganon' 'Windblight Ganon']
#
# number of allies (after duplicates removed): 571
# number of enemies (after duplicates removed): 63
# number of bosses (after duplicates removed): 22

# %%
import pandas as pd
from itertools import chain

types = ["Ally","Enemy","Boss"]
pddict = [{"type": char_type, "name": name} for char_type,names in zip(types,[allies,enemies,bosses]) for name in names]
#print(pddict)
dfdata = [allies,enemies,bosses]
df = pd.DataFrame(data=pddict)
display(df)

df.to_csv('ZeldaCharacters.csv')
# Out:
#      type                  name
# 0    Ally                  Agus
# 1    Ally                   Aji
# 2    Ally           Akh Va'quot
# 3    Ally                 Akrah
# 4    Ally                 Aliza
# ..    ...                   ...
# 651  Boss    Stone Talus (Rare)
# 652  Boss  Stone Talus (Senior)
# 653  Boss   Thunderblight Ganon
# 654  Boss     Waterblight Ganon
# 655  Boss      Windblight Ganon
#
# [656 rows x 2 columns]

# %% [markdown]
# You've made it! Now, you have a clean file listing all characters in BotW and their role. By following the same strategy you used to download the pages above, you can now use the API and download each character page. For each character, save the resulting page content in a txt file.
#
# **Note**:
# 1. the name of the character corresponds to the title of its page (where spaces are replaced with underscores). So, the title of `Princess Zelda`'s page is `Princess_Zelda`
# 2. some of your character's names could actually redirect to a different page. Add a check to find any redirect in a page description. (**hint**: the description will be in the form `#REDIRECT [[PAGENAME]]` so you should use `PAGENAME` in your query instead)

# %%
allies
# Out:
# array(['Agus', 'Aji', "Akh Va'quot", 'Akrah', 'Aliza', 'Amali', 'Ami',
#        'Amira', 'Anche', 'Anly', 'Ardin', 'Ariane', 'Armes', 'Ashai',
#        'Ashe', 'Aster', 'Aurie Taamu', 'Axyl', 'Aya', 'Azu', 'Babi',
#        'Baddek', 'Bamboo', 'Banji', 'Bareeda Naag', 'Bargoh', 'Barta',
#        'Baumar', 'Bayge', 'Bazz', 'Bedoli', 'Beedle', 'Benja', 'Benny',
#        'Bertri', 'Bladon', 'Bludo', 'Blynne', 'Bohrin', 'Boldon',
#        'Bolson', 'Bosh Kala', 'Botrick', 'Bozai', 'Branli', 'Breen',
#        'Brigo', 'Brokka', 'Bugut', 'Buliara', 'Cado', 'Calip', 'Calisa',
#        'Calyban', 'Cambo', 'Canni', 'Canolo', 'Cara', 'Cecili', 'Celessa',
#        'Chaas Qeta', 'Chabi', 'Cherry', 'Chessica', 'Chio', 'Chork',
#        'Chumin', 'Cima', 'Claree', 'Clavia', 'Cleff', 'Cloyne', 'Cotera',
#        'Cottla', 'Cree', 'Daag Chokah', 'Dabi', 'Dagah Keek', 'Dah Hesho',
#        'Dah Kaso', 'Dai', 'Daka Tuss', 'Dako Tah', 'Dalia', 'Damia',
#        'Danda', 'Danton', 'Dantz', 'Daqa Koh', 'Daqo Chisay', 'Darton',
#        'Daruk', 'Dauntless', 'Dayto', 'Daz', 'Deltan', 'Dento',
#        'Dila Maag', 'Dillie', 'Dina', 'Dinraal', 'Dmitri', 'Domidak',
#        'Dorian', 'Dorill', 'Dorrah', 'Douma', "Dow Na'eh", 'Drak',
#        'Dugby', 'Dunba Taag', 'Dunma', 'Eighth Heroine', 'Emri', 'Ena',
#        'Endai', 'Epona', 'Eryck', 'Essa', 'Estan', 'Etsu Korima',
#        'Falmark', 'Farosh', 'Fegran', 'Fin', 'Finley', 'Flavi', 'Flaxel',
#        'Frelly', 'Frita', 'Fronk', 'Fugo', 'Furosa', 'Fyson', 'Gaddison',
#        'Gaile', 'Galli', 'Garill', 'Garini', 'Garshon', 'Gartan',
#        "Gee Ha'rah", 'Geggle', 'Genli', 'Gesane', 'Giro', 'Gleema',
#        'Glendo', 'Goflam', 'Goma Asaagh', 'Gonguron', 'Gorae Torr',
#        'Gotter', 'Granté', 'Grapp', 'Greta', 'Greyson', 'Gruve', 'Guy',
#        'Ha Dahamar', 'Hagie', 'Haite', 'Harlow',
#        'Harry (Breath of the Wild)', 'Harth', 'Hawa Koth', 'Heehl',
#        'Hestu', 'Hia Miu', 'Hila Rao', 'Hino', 'Horned Statue', 'Hoz',
#        'Huck', 'Hudson', 'Hunnie', 'Hylia', 'Impa', 'Isha', 'Ishto Soh',
#        'Ivee', 'Izra', 'Ja Baij', 'Jana', 'Jee Noh', 'Jengo', 'Jerrin',
#        'Jiahto', 'Jini', "Jitan Sa'mi", 'Jogo', 'Joloo Nah', 'Jora',
#        'Joute', 'Juannelle', 'Jules', 'Juney', "Ka'o Makagh",
#        "Kaam Ya'tak", 'Kabetta', 'Kachoo', 'Kah Mael', 'Kah Okeo',
#        'Kah Yah', 'Kaifa', 'Kairo', 'Kalani', 'Kam Urog', 'Kampo',
#        'Kaneli', 'Kanny', 'Kapson', 'Karin', 'Karsh', 'Karson', 'Kass',
#        'Katah Chuki', 'Katosa Aug', 'Katta', 'Kay Noh', 'Kaya Wan',
#        'Kayden', 'Kayra Mah', 'Kaysa', "Ke'nai Shakah", 'Keeha Yoog',
#        'Keh Namut', 'Keive Tala', 'Kema Kosassa', 'Kema Zoos', 'Kenyo',
#        'Keo Ruug', 'Ketoh Wawai', 'Keye', 'Kheel', 'Khini', 'Kiah Toza',
#        'Kiana', 'Kihiro Moh', 'Kilton', 'Kima', 'King Dorephan',
#        'King Rhoam', 'Kinov', 'Kish', 'Kodah', 'Kohm', 'Koko', 'Konba',
#        'Konora', 'Korgu Chideh', "Korsh O'hu", 'Kotta', 'Kotts', 'Koyin',
#        'Krane', 'Kuh Takkar', 'Kuhn Sidajj', 'Kula', 'Kyra', 'Laflat',
#        'Laine', 'Laissa', 'Lakna Rokee', 'Lanno Kooh', 'Laroba', 'Laruta',
#        'Lashley', 'Lasli', 'Lawdon', 'Ledo', 'Leekah', 'Leena', 'Leop',
#        'Lester', 'Letty', 'Liana', 'Link', 'Lonni', 'Loone', 'Lorn',
#        'Lukan', 'Lyndae', 'Maag Halan', "Maag No'rah", 'Maca', 'Magda',
#        'Maike', 'Maka Rah', 'Makure', 'Malanya', 'Malena',
#        'Manny (Breath of the Wild)', 'Marot', 'Marta',
#        'Mary (Breath of the Wild)', 'Maypin', 'Mayro', 'Mazli', 'Medda',
#        'Meeshy', 'Meghyn', 'Mei', 'Mellie', 'Merina', 'Mezza Lo',
#        'Mijah Rokee', 'Mils', 'Mimo', 'Mimos', 'Mina', 'Mipha',
#        'Mirro Shaz', 'Misa', 'Misae Suma', 'Misko', "Mo'a Keet", 'Modar',
#        'Mogg Latan', 'Moggs', 'Molli', 'Molo', 'Monari', 'Monkton',
#        'Monya Toma', 'Moza', 'Mozo Shenno', 'Muava', 'Mubs', 'Muwo Jeem',
#        'Muzu', 'Myahm Agana', 'Myti', 'Nack', 'Naddon', 'Nali',
#        'Namika Ozz', 'Nanna', 'Narah', 'Nat', 'Natie', 'Naydra', 'Nazbi',
#        "Ne'ez Yohma", 'Nebb', 'Nekk', 'Nell', 'Nellie', 'Nikki', 'Nobiro',
#        'Nobo', 'Noe Rajee', 'Notts', 'Noya Neha', 'Numar', 'Oaki',
#        'Offrak', 'Old Man', 'Oliff', 'Olkin', 'Ollie', 'Olu', 'Oman Au',
#        'Onya', 'Owa Daim', 'Ozunda', 'Padda', 'Padok', 'Palme', 'Parcy',
#        'Pasha', 'Patricia', 'Paya', 'Pearle', 'Peeks', 'Pelison', 'Pepp',
#        'Perda', 'Perosa', 'Phanna', 'Piaffe', 'Pikango', 'Pirou', 'Pitar',
#        'Ploka', 'Pokki', 'Pondo', 'Ponthos', 'Prima', 'Princess Zelda',
#        'Prissen', 'Pritana', 'Pruce', 'Pumaag Nitae', 'Purah', 'Pyle',
#        'Pyra', 'Qaza Tokki', 'Qua Raym', 'Quince', 'Qukah Nata', 'Ralera',
#        'Ramella', 'Raqa Zunzo', 'Reagah', 'Ree Dahee', 'Reede', 'Reeza',
#        'Regan', 'Rensa', 'Revali', 'Rex', 'Rhodes', 'Rhondson', 'Riju',
#        'Rik', 'Rima', 'Rin Oyaa', 'Ripp', 'Risa', 'Ritaag Zumo', 'Rivan',
#        'Robbie', 'Robsten', 'Rogaro', 'Rohan', 'Rohta Chigah', 'Rok Uwog',
#        'Rola', 'Romah', 'Rona Kachta', 'Ronn', 'Roscoe', 'Rota Ooh',
#        'Rotana', 'Rozel', 'Rucco Maag', 'Rudi', 'Ruli', 'Russ',
#        'Ruvo Korbah', "Saas Ko'sah", 'Sagessa', 'Sah Dahaj', 'Saki',
#        'Sasa Kai', 'Satty', 'Saula', 'Savelle', 'Sayge', 'Sebasto',
#        'Sefaro', 'Seggin', 'Seldon', 'Selmie', 'Senna', 'Sesami',
#        'Seven Heroines', 'Sha Gehma', 'Sha Warvo', 'Shabonne',
#        'Shada Naw', 'Shae Katha', 'Shae Loya', "Shae Mo'sah", 'Shai Utoh',
#        'Shai Yota', 'Shaillu', 'Shamae', 'Shay', 'Shee Vaneer',
#        'Shee Venath', 'Sheem Dagoze', 'Sheh Rata', 'Sherfin', 'Shibo',
#        'Shira Gomar', 'Sho', 'Sho Dantu', 'Shoda Sah', 'Shoqa Tatone',
#        'Shora Hah', 'Sidon', 'Slergo', 'Smaude', 'Soh Kofi', 'Sophie',
#        'Sorelia', 'Spera', 'Spinch (Horse)', 'Spinch (Hylian)', 'Spoone',
#        'Sprinn', 'Stamm', 'Steen', 'Strade', 'Straia', 'Sudrey',
#        'Suma Sahma', 'Sumati', 'Suzuna', 'Symin', "Ta'loh Naeg",
#        'Tah Muhl', "Tahno O'ah", 'Takama Shiri', 'Tali', 'Tamana',
#        'Tanko', 'Tasho', 'Tasseren', 'Tauma', 'Tawa Jinn', 'Teake',
#        'Teba', 'Teebo', 'Teli', "Tena Ko'sah", 'Tenne', 'Tera', 'Thadd',
#        'The Great Deku Tree', 'Tho Kayu', 'To Quomo', 'Toffa',
#        'Toh Yahsa', 'Tokk', 'Toma', 'Tona', 'Toren', 'Torfeau',
#        'Toto Sah', 'Totsuna', 'Tottika', 'Tray', 'Traysi', 'Trello',
#        'Trissa', 'Trott', "Tu Ka'loh", 'Tula', 'Tulin', 'Tumbo',
#        'Tutsuwa Nima', 'Tye', 'Uma', 'Urbosa', 'Varke', 'Verla', 'Vilia',
#        'Volcon', 'Voo Lota', 'Wabbin', 'Wahgo Katta', 'Walton', 'Worten',
#        'Ya Naga', 'Yah Rin', 'Yaido', 'Yammo', 'Yolero', 'Yowaka Ita',
#        'Yunobo', 'Zalta Wa', 'Ze Kasho', 'Zooki', 'Zorona', 'Zumi',
#        'Zuna Kai', 'Zuta', 'Zyle'], dtype='<U26')

# %%
def createstuff(title):
    baseurl = "https://zelda.fandom.com/api.php?"
    action = "action=query"
    title_a = "titles="+title
    content = "prop=revisions&rvprop=content&rvslots=*"
    dataformat ="format=json"

    query_a = "{}{}&{}&{}&{}".format(baseurl, action, content, title_a, dataformat)
    wikiresponse = urllib.request.urlopen(query_a)
    wikidata = wikiresponse.read()
    wikitext_a = wikidata.decode('utf-8')
    json_a = json.loads(wikitext_a)
    page0 = list(json_a['query']['pages'].keys())[0]
    a_text = json_a['query']['pages'][page0]['revisions'][0]['slots']['main']['*']
    return a_text

# %%
# Saving the character pages in txt file #
from tqdm.notebook import tqdm
import os
#script_dir = os.path.dirname(__file__) # <-- absolute dir the script is in
script_dir = os.getcwd()
folder_dir = "descriptions\\" 
path = os.path.join(script_dir, folder_dir)

characters = list(df['name'])
characters = [char.replace(" ","_") for char in characters]
#print(characters)
for char in tqdm(characters):
    try:
        temp = createstuff(char)
        with open(path+char+".txt",'w') as x:
            json.dump(temp,x)
    except:
        print(char)
# Out:
# 'for char in tqdm(characters):\n    try:\n        temp = createstuff(char)\n        with open(path+char+".txt",\'w\') as x:\n            json.dump(temp,x)\n    except:\n        print(char)'

# %% [markdown]
# ---
#
# # Part B: Building the network
#
# Now, we're going to build the BotW NetworkX directed graph, which includes all good characters, enemies, and bosses.
#
# The nodes in the network will be all the characters, and we will place an edge between nodes $A$ and $B$ if the Zelda wiki page of node $A$ links to the Zelda Wiki page of node $B$.

# %%
YouTubeVideo("eciQ6qgRD-4", width=800, height=450)

# %%
YouTubeVideo("J7SF0Xs2PHM", width=800, height=450)

# %% [markdown]
# > _Exercise 1_: Build the network of BotW Characters
# >
# > Now we can build the network. Isn't this a little bit cool? What a dataset :)
# >
# > The overall strategy for this is the following:
# > Take the pages you have downloaded for each character.
# > Each page corresponds to a character, which is a node in your network.
# > Find the Race and Gender of a character in their Infobox and use regular expressions to extract them. Then, find all the hyperlinks in a character's page that link to another node of the network (e.g. another character).
# > There are many ways to do this, but below, I've tried to break it down into natural steps.
# > Keep in mind that the network should include all characters (allies, enemies, and bosses).
# >
# >
# > * Use regular expressions to extract all outgoing links from each of the pages you downloaded above. Remember that links have different [flavors](https://zelda.fandom.com/wiki/Guidelines:Getting_Started), these are the ones we need (they seem a lot but you've already built the patterns in 1. and 2. and just need to add a condition to them):
#       1. direct links, i.e. [[name of character]] or {{Term|BotW|name of character|link}}
#       2. links using text, i.e. [[Princess Zelda|Zelda]] or {{Term|Series|Princess Zelda|link|display=Zelda}}
#       3. links to pages that have parentheses, i.e. [[Ocarina of Time (Item)|]] or {{Term|Series|Ocarina of Time (Item)|link}}
#       4. links using plural terms, i.e. [[Heart]]s or {{Plural|Series|Heart|link}}
#       5. links to sections of another page, i.e. [[Link#Breath of the Wild]] or {{Term|BotW|Link|link}}
# >
# > * For each link you extract, check if the target is a character. If yes, keep it. If no, discard it.
# > * Use a NetworkX [`DiGraph`](https://networkx.github.io/documentation/development/reference/classes.digraph.html) to store the network. Store also the properties of the nodes (i.e. Role, Race, and Gender).
# > * When you have finished, you'll notice that some nodes do not have any edge. Those are isolated nodes, you may *discard* them from the network.
# >
# > **Note**: When you add a node to the network, also include an `attribute` for each node characteristic (i.e. an attribute that specifies Role, Race, and Gender)

# %%
links = []
for node in tqdm(characters):
    try:
        with open(path+node+".txt","r") as f:
            node_description = f.read()
        
        pattern1 = r'\[\[(.*?)(?:\|.*?|\#Breath of the Wild)?\]\]'
        pattern2 = r'\{\{(?:Plural|Term)\|BotW\|(.*?)(?:\|display.*?)?(\|link)?(?:\|display.*?)?\}\}'
        
        #find patterns of two types and filter non-links
        links_pattern1 = list(re.findall(pattern1, node_description))
        links_pattern2 = [l[0] for l in re.findall(pattern2, node_description) if "|link" in l]
        
        links_total = [l for l in set(links_pattern1+links_pattern2) if l in df.name.values]
        
        links.append(links_total)

    except:
        print("failure with: ",node)
# Out:
#   0%|          | 0/656 [00:00<?, ?it/s]
# failure with:  Granté

# %%
links
# Out:
# [['Link'],
#  ['Offrak', 'Fyson', 'Pelison'],
#  [],
#  ['Zumi', 'Onya', 'Link', 'Garshon'],
#  ['Link'],
#  ['Cree', 'Kotts', 'Kass', 'Notts', 'Kheel', 'Genli'],
#  ['Yolero', 'Izra', 'Link'],
#  ['Azu', 'Pruce', 'Ivee', 'Link', 'Purah', 'Nikki'],
#  ['Pokki', 'Link', 'Furosa'],
#  ['Cima', 'Shay', 'Link', 'Kampo'],
#  ['Nellie', 'Estan', 'Spera', 'Jules'],
#  ['Lester', 'Galli', 'Link'],
#  ['Sebasto', 'Link', 'Numar'],
#  ['Dina', 'Risa', 'Pasha', 'Link'],
#  ['Kish', 'Breen', 'Shamae', 'Link'],
#  ['Bolson', 'Medda', 'Karin', 'Link'],
#  ['Isha', 'Ashai'],
#  ['Dorill', 'Pelison'],
#  ['Rudi', 'Khini', 'Robbie'],
#  ['Amira', 'Karin', 'Sefaro', 'Pruce', 'Ivee', 'Purah', 'Link'],
#  ['Teake', 'Smaude', 'Malena', 'Link', 'Marta'],
#  ['Yammo', 'Nazbi', 'Link', 'Savelle'],
#  ['Baumar'],
#  ['Malanya',
#   'Hylia',
#   'Chork',
#   'Dabi',
#   'Kenyo',
#   'Konba',
#   'Sho',
#   'Ena',
#   'Geggle'],
#  [],
#  ['Bludo', 'Yunobo', 'Link'],
#  ['Riju', 'Leena', 'Liana', 'Link', 'Kotta', 'Perda'],
#  ['Bamboo', 'Selmie', 'Falmark'],
#  ['Kabetta', 'Daruk', 'Heehl'],
#  ['Rivan', 'Gaddison', 'King Dorephan', 'Link'],
#  ['Laissa', 'Link'],
#  ['Link'],
#  ['Robsten', 'Vilia', 'Link'],
#  ['Link'],
#  ['Riju', 'Link'],
#  ['Gonguron'],
#  ['Daruk', 'Yunobo', 'Kass'],
#  ['Link'],
#  [],
#  ['Bolson', 'Naddon', 'Link'],
#  ['Hudson', 'Link', 'Boldon', 'Karson'],
#  [],
#  [],
#  ['Link'],
#  ['Link'],
#  ['Epona'],
#  ['Decayed Guardian', 'Guardian Stalker', 'Link'],
#  ['Link'],
#  ['Claree', 'Link'],
#  ['Riju', 'Teake', 'Princess Zelda', 'Link'],
#  ['Calamity Ganon', 'Dorian', 'Rola', 'Link', 'Impa'],
#  [],
#  ['Link'],
#  ['Dalia', 'Link'],
#  ['Link'],
#  ['Epona'],
#  ['Blue Bokoblin', 'Palme', 'Bokoblin', 'Sesami', 'Oliff', 'Link', 'Flaxel'],
#  ['Ashai', 'Link', 'Isha'],
#  ['Stalkoblin', 'Link'],
#  ['Impa', 'Guardian Stalker', 'Link', 'King Rhoam'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Kilton', 'Bokoblin', 'Link', 'Blue Bokoblin', 'Black Bokoblin'],
#  [],
#  ['Link'],
#  ['Hestu', 'Link'],
#  ['Geggle', 'Kass', 'Link'],
#  ['Link'],
#  ['Link'],
#  ['Lasli', 'Nanna', 'Link'],
#  ['Reede', 'Karin', 'Link'],
#  ['Tona', 'Link'],
#  ['Armes', 'Link'],
#  ['Kaysa', 'Tera', 'Dorian', 'Link'],
#  ['Dorian', 'Link', 'Impa', 'Koko'],
#  ['Kaneli', 'Kheel', 'Kotts', 'Amali', 'Genli', 'Kass', 'Link', 'Notts'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Lynel', 'Golden Lynel', 'Silver Lynel'],
#  [],
#  [],
#  ['Makure', 'Kalani', 'Lorn', 'Link', 'Pearle', 'Ashai'],
#  ['Link'],
#  ['Makure', 'Kalani', 'Link'],
#  [],
#  ['Link'],
#  [],
#  [],
#  ['Shibo', 'Sagessa', 'Tasseren', 'Link', 'Rensa'],
#  ['Bludo',
#   'Revali',
#   'Yunobo',
#   'Dark Beast Ganon',
#   'Bokoblin',
#   'Princess Zelda',
#   'Link',
#   'Fireblight Ganon',
#   'Calamity Ganon',
#   'King Rhoam'],
#  ['Nazbi'],
#  ['Guardian Stalker'],
#  ['Link'],
#  ['Link', 'Ashai'],
#  ['Mipha', 'Link', 'Marot'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Bokoblin', 'Jora', 'Link'],
#  ['Link', 'Ashai'],
#  ['Naydra', 'Farosh'],
#  ['Gleema', 'Kaifa', 'Jana', 'Link'],
#  ['Misko', 'Link', 'Prissen'],
#  ['Yiga Blademaster',
#   'Cottla',
#   'Cado',
#   'Lasli',
#   'Impa',
#   'Link',
#   'Mellie',
#   'Cotera',
#   'Paya',
#   'Koko'],
#  ['Bludo', 'Axyl'],
#  ['Riju', 'Link', 'Merina'],
#  ['Mipha', 'Link', 'Sidon'],
#  [],
#  ['Bludo', 'Yunobo', 'Link'],
#  ['Grapp', 'Link'],
#  [],
#  ['Trello', 'Dunma', 'Sidon', 'Rivan', 'Mipha', 'Link', 'King Dorephan'],
#  ['Seven Heroines', 'Bozai', 'Link'],
#  ['Vilia', 'Link'],
#  ['Banji', 'Hestu', 'Link', 'Kenyo'],
#  [],
#  ['Malanya', 'Link'],
#  ['Gruve'],
#  ['Frelly', 'Link'],
#  ['Frita', 'Maike', 'Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Naydra', 'Link', 'Dinraal'],
#  ['Riju', 'Link'],
#  ['Russ'],
#  ['Sidon', 'Kayden', 'Link', 'Kodah'],
#  [],
#  [],
#  ['Link', 'Kohm'],
#  ['Link'],
#  ['Keye', 'Dento', 'Mei', 'Link', 'Tumbo'],
#  ['Slergo', 'Rohan', 'Igneo Talus'],
#  ['Pokki', 'Link', 'Anche', 'Greta'],
#  ['Hudson', 'Link', 'Misa'],
#  ['Rivan', 'Bazz'],
#  [],
#  [],
#  ['Guardian Stalker', 'Link'],
#  [],
#  [],
#  ['Link'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Kaifa', 'Jana', 'Dmitri'],
#  ['Keese', 'Link'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Bladon'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Princess Zelda', 'Hinox'],
#  ['Bludo', 'Dugby'],
#  ['Link'],
#  ['Bolson',
#   'Dorill',
#   'Bohrin',
#   'Hudson',
#   'Rhondson',
#   'Axyl',
#   'Jengo',
#   'Pelison'],
#  ['Lynel', 'Link', 'Sidon', 'King Dorephan'],
#  ['Link'],
#  [],
#  ['Ruli', 'Hunnie'],
#  ['Link', 'Myti'],
#  ['Danton', 'Link'],
#  ['Monkton', 'Mary (Breath of the Wild)'],
#  ['Kaneli', 'Revali', 'Teba', 'Molli', 'Calamity Ganon', 'Link'],
#  [],
#  ['Kabetta', 'Bayge'],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Link'],
#  ['Teebo', 'Hylia'],
#  ['Kilton'],
#  ['Revali', 'Verla'],
#  ['Bolson', 'Link', 'Rhondson'],
#  ['Ruli', 'Hagie'],
#  ['Impa', 'Princess Zelda'],
#  ['Calamity Ganon',
#   'Princess Zelda',
#   'Link',
#   'Fire Wizzrobe',
#   'Paya',
#   'Hylia',
#   'Bokoblin',
#   'Purah',
#   'King Rhoam'],
#  ['Cara', 'Link'],
#  [],
#  ['Azu', 'Pruce', 'Link', 'Amira'],
#  [],
#  [],
#  ['Gleema', 'Hudson', 'Link', 'Dmitri', 'Kaifa'],
#  [],
#  ['Greyson', 'Dorill', 'Bludo', 'Bohrin'],
#  ['Symin', 'Nanna', 'Purah', 'Link', 'Robbie'],
#  ['Mipha'],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Juney'],
#  [],
#  ['Dillie', 'Bokoblin', 'Link'],
#  ['Link'],
#  [],
#  ['Link'],
#  ['Jogo'],
#  [],
#  [],
#  ['Heehl', 'Bayge'],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  [],
#  ['Jana', 'Gleema', 'Dmitri'],
#  ['Yunobo'],
#  ['Frita', 'Makure', 'Ashai', 'Pearle', 'Dalia', 'Danda'],
#  [],
#  [],
#  ['Teba'],
#  [],
#  ['Hudson', 'Hylia', 'Mipha', 'Link', 'Rhondson'],
#  ['Clavia', 'Reede'],
#  [],
#  ['Bolson', 'Sophie', 'Link'],
#  ['Kheel',
#   'Kotts',
#   'Amali',
#   'Genli',
#   'Princess Zelda',
#   'Notts',
#   'Cree',
#   'Farosh'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Riju', 'Link'],
#  [],
#  [],
#  ['Finley', 'Link', 'Kodah'],
#  [],
#  ['Toren', 'Tera', 'Cotera'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Link'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Fronk', 'Mipha', 'Mei', 'Link', 'Tumbo'],
#  ['Kaneli', 'Kotts', 'Amali', 'Genli', 'Kass', 'Link', 'Notts', 'Cree'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hoz'],
#  [],
#  ['Muzu', 'Princess Zelda', 'Mipha', 'Link'],
#  ['Impa', 'Princess Zelda', 'Old Man', 'Link', 'Calamity Ganon'],
#  ['Kiana', 'Link'],
#  ['Link'],
#  ['Sidon', 'Kayden', 'Mipha', 'Finley', 'Link', 'King Dorephan'],
#  ['Frelly', 'Link'],
#  ['Cottla', 'Dorian', 'Link'],
#  ['Link'],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Liana', 'Barta', 'Link'],
#  [],
#  ['Dantz', 'Link'],
#  ['Bludo'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Kula', 'The Great Deku Tree'],
#  ['Link'],
#  ['Lynel', 'Mipha', 'King Dorephan'],
#  ['Tali', 'Link'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Trello', 'Sidon', 'Tona', 'Mipha', 'Link', 'King Dorephan', 'Tula'],
#  ['Riju', 'Link'],
#  ['Nanna', 'Link', 'Claree'],
#  [],
#  ['Sidon', 'Dento', 'Link'],
#  [],
#  ['Riju', 'Liana', 'Barta', 'Link', 'Kotta'],
#  ['Purah', 'Prima'],
#  ['Link'],
#  [],
#  ['Riju', 'Barta', 'Link', 'Kotta', 'Leena'],
#  ['Impa',
#   'Calamity Ganon',
#   'Princess Zelda',
#   'Kass',
#   'Old Man',
#   'Paya',
#   'Hylia',
#   'Epona',
#   'King Rhoam'],
#  ['Stalnox'],
#  ['Link', 'Roscoe'],
#  ['Dalia', 'Link'],
#  ['Riju', 'Link'],
#  ['Strade'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Link'],
#  [],
#  ['Estan', 'Vilia', 'Link'],
#  [],
#  ['Kalani', 'Dalia', 'Pearle', 'Danda', 'Ashai'],
#  ['Link'],
#  ['Link', 'Molduga'],
#  ['Link'],
#  ['Dento', 'Link'],
#  ['Riju', 'Babi', 'Link'],
#  ['Harry (Breath of the Wild)', 'Monkton'],
#  ['Link'],
#  ['Ozunda'],
#  ['Link'],
#  ['Aster', 'Princess Zelda', 'Link'],
#  [],
#  ['Bokoblin', 'Nat'],
#  ['Keye', 'Fronk', 'Link', 'Tumbo'],
#  ['Steen', 'Olkin'],
#  ['Dorrah', 'Link'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Mina'],
#  ['Link'],
#  [],
#  ['Mils', 'Link'],
#  ['Muzu',
#   'Princess Zelda',
#   'Link',
#   'Waterblight Ganon',
#   'Sidon',
#   'King Rhoam',
#   'King Dorephan'],
#  [],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Domidak', 'Link', 'Prissen'],
#  [],
#  [],
#  [],
#  ['Monari'],
#  ['Harth'],
#  [],
#  ['Moggs'],
#  ['Link'],
#  [],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Link'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Sidon', 'Mipha', 'Link', 'King Dorephan'],
#  [],
#  ['Haite', 'Link', 'Trott'],
#  ['Link', 'Sayge'],
#  ['Boldon'],
#  ['Riju', 'Urbosa', 'Pritana', 'Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Symin', 'Lasli', 'Jerrin', 'Purah', 'Robbie', 'Impa', 'Claree'],
#  ['Amira', 'Nebb', 'Nikki', 'Link', 'Nack'],
#  ['Meghyn', 'Bokoblin'],
#  ['Link'],
#  ['Link', 'Dinraal', 'Farosh'],
#  [],
#  [],
#  ['Narah', 'Nikki', 'Link', 'Nack'],
#  [],
#  ['Blue Moblin', 'Link'],
#  ['Lorn', 'Ardin', 'Risa', 'Link'],
#  ['Amira', 'Narah', 'Nebb', 'Purah', 'Link', 'Nack'],
#  ['Link'],
#  ['Pitar', 'Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  [],
#  ['Aji'],
#  ['Calamity Ganon', 'Princess Zelda', 'Link'],
#  ['Sesami', 'Link'],
#  ['Link', 'Mellie'],
#  ['Link', 'Olkin', 'Mellie'],
#  ['Romah', 'Link'],
#  [],
#  [],
#  [],
#  ['Link'],
#  ['Riju', 'Patricia', 'Link'],
#  ['Link'],
#  [],
#  [],
#  ['Link', 'Ashai'],
#  ['Padda', 'Riju', 'Link'],
#  ['Cado', 'Dorian', 'Impa', 'Princess Zelda', 'Purah', 'Link'],
#  ['Makure', 'Ashai', 'Kalani', 'Urbosa', 'Spera', 'Rotana', 'Link'],
#  ['The Great Deku Tree', 'Link'],
#  ['Bolson', 'Greyson', 'Hudson', 'Axyl', 'Rhondson'],
#  ['Link'],
#  ['Wabbin', 'Barta', 'Yaido', 'Sumati', 'Pyra', 'Ashai'],
#  [],
#  [],
#  ['Link'],
#  ['Link', 'Master Kohga', 'Impa'],
#  ['Link'],
#  [],
#  ['Traysi', 'Riju', 'Reeza', 'Link'],
#  ['Link', 'Furosa'],
#  ['Link'],
#  [],
#  ['Manny (Breath of the Wild)', 'Link'],
#  ['Impa', 'Kass', 'Yiga Footsoldier', 'Link', 'Hylia', 'Daruk', 'King Rhoam'],
#  ['Domidak', 'Misko', 'Link'],
#  ['Riju', 'Nali', 'Urbosa', 'Link'],
#  ['Amira', 'Azu', 'Ivee', 'Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Monk Maz Koshia',
#   'Symin',
#   'Robbie',
#   'Impa',
#   'Princess Zelda',
#   'Calamity Ganon',
#   'Paya'],
#  ['Bludo', 'Rogaro'],
#  ['Saula', 'Rotana', 'Yaido', 'Perda', 'Sumati'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Satty'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Rozel', 'Purah', 'Link', 'Rhodes'],
#  ['Offrak', 'Calamity Ganon'],
#  ['Calamity Ganon', 'Hylia', 'Link'],
#  ['Sidon', 'Link'],
#  [],
#  ['Karin', 'Purah', 'Link', 'Clavia'],
#  ['Buliara', 'Riju', 'Ploka', 'Link'],
#  [],
#  ['Tasseren', 'Darton', 'Shibo', 'Purah', 'Link'],
#  ['Windblight Ganon',
#   'Daruk',
#   'Urbosa',
#   'Princess Zelda',
#   'Link',
#   'King Rhoam'],
#  [],
#  ['Ralera', 'Link'],
#  ['Hudson', 'Link'],
#  ['Patricia', 'Teake', 'Urbosa', 'Link', 'Buliara'],
#  ['Steen', 'Olkin'],
#  ['Buliara', 'Riju', 'Patricia', 'Link'],
#  [],
#  ['Vilia', 'Link'],
#  ['Nellie', 'Dina', 'Pasha', 'Link', 'Ashai'],
#  ['Calamity Ganon', 'Hylia', 'Link'],
#  ['Trello', 'Dunma', 'Bazz', 'Gaddison', 'Link'],
#  ['Jerrin', 'Princess Zelda', 'Purah', 'Link', 'Calamity Ganon'],
#  ['Benja', 'Vilia', 'Link'],
#  ['Pyle'],
#  ['Fugo', 'Slergo', 'Igneo Talus'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Cado', 'Link'],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Link'],
#  [],
#  ['Seven Heroines', 'Urbosa', 'Link', 'Pearle'],
#  ['Ralera'],
#  [],
#  [],
#  ['Hagie', 'Hunnie'],
#  ['Fin'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Darton', 'Shibo', 'Link'],
#  [],
#  ['Kaneli', 'Revali', 'Tulin', 'Link', 'Teba'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Satty', 'Link', 'Quince'],
#  ['Yaido', 'Link'],
#  [],
#  ['Senna', 'Sefaro'],
#  [],
#  ['Azu', 'Senna', 'Purah', 'Link', 'Sayge'],
#  ['Mipha', 'Link'],
#  ['Link', 'Sayge', 'Sophie'],
#  [],
#  ['Sefaro', 'Sayge'],
#  ['Palme', 'Link', 'Oliff', 'Flaxel', 'Canolo'],
#  ['Rotana', 'Link', 'Eighth Heroine'],
#  [],
#  [],
#  ['Tali', 'Link'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  [],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Vilia', 'Link'],
#  ['Ashe'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Tasseren', 'Darton', 'Link', 'Rensa'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  [],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Muzu', 'Mipha', 'Link', 'Calamity Ganon', 'King Dorephan'],
#  ['Fugo', 'Rohan'],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Karson', 'Link', 'Seldon'],
#  [],
#  ['Link'],
#  ['Spinch (Hylian)'],
#  [],
#  ['Naydra', 'Link'],
#  [],
#  [],
#  ['Calamity Ganon', 'Link', 'Olkin', 'Trissa'],
#  ['Link', 'Lyndae'],
#  [],
#  ['Riju', 'Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Saula', 'Rotana', 'Yaido', 'Perda', 'Pyra'],
#  [],
#  ['Calamity Ganon', 'Purah', 'Link', 'Impa'],
#  [],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Shabonne', 'Teli'],
#  ['Link'],
#  [],
#  [],
#  ['Link', 'Rensa'],
#  ['Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Buliara', 'Riju', 'Link'],
#  ['Revali',
#   'Tulin',
#   'Calamity Ganon',
#   'Saki',
#   'Link',
#   'Harth',
#   'Windblight Ganon'],
#  ['Reede', 'Horned Statue', 'Link'],
#  ['Robbie', 'Bokoblin', 'Link', 'Tali', 'Calamity Ganon'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Gleema', 'Epona', 'Kaifa', 'Jana', 'Link', 'Dmitri'],
#  ['Kaysa', 'Link', 'Cotera'],
#  ['Link', 'Seldon'],
#  ['Princess Zelda', 'Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Princess Zelda', 'Link'],
#  [],
#  ['Uma', 'Purah', 'Link'],
#  [],
#  ['Sidon', 'Laruta', 'Link', 'Cleff', 'Tula'],
#  ['Kaysa'],
#  ['Sidon', 'Hinox'],
#  [],
#  [],
#  [],
#  ['Volcon'],
#  ['Riju',
#   'Ploka',
#   'Strade',
#   'Molduga',
#   'Naydra',
#   'Molduking',
#   'Princess Zelda',
#   'Link',
#   'Dinraal',
#   'Lyndae',
#   'King Rhoam',
#   'Muava',
#   'Farosh',
#   'Ashai'],
#  ['Dunma', 'Rivan', 'Dento', 'Mipha', 'Link'],
#  ['Steen', 'Olkin'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Waterblight Ganon', 'Sidon', 'Link', 'King Dorephan'],
#  ['Saki', 'Link', 'Teba'],
#  ['Keye', 'Calamity Ganon', 'Fronk', 'Mipha', 'Mei', 'Link'],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Calamity Ganon', 'Link'],
#  ['Riju',
#   'Pearle',
#   'Revali',
#   'Thunderblight Ganon',
#   'Kass',
#   'Princess Zelda',
#   'Calamity Ganon',
#   'King Rhoam',
#   'Yiga Footsoldier'],
#  [],
#  [],
#  ['Riju', 'Benja', 'Link'],
#  ['Tray'],
#  [],
#  ['Wabbin', 'Perda'],
#  [],
#  ['Link'],
#  [],
#  [],
#  [],
#  ['Saula', 'Rotana', 'Perda', 'Sumati', 'Pyra'],
#  [],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  ['Bludo', 'Sentry', 'Daruk', 'Link', 'Fireblight Ganon', 'Black Moblin'],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  [],
#  [],
#  ['Calamity Ganon', 'Link', 'Hylia'],
#  [],
#  ['Link'],
#  ['Blue Bokoblin'],
#  ['Golden Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Stalizalfos',
#   'Lizalfos',
#   'Electric Lizalfos',
#   'Blue Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Silver Lizalfos'],
#  ['Blue Moblin'],
#  ['Ice Wizzrobe', 'Ice Chuchu', 'Ice Keese'],
#  ['Bokoblin', 'Link', 'White-Maned Lynel', 'Blue Bokoblin'],
#  ['Golden Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Stalizalfos',
#   'Lizalfos',
#   'Electric Lizalfos',
#   'Cursed Lizalfos',
#   'Black Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Silver Lizalfos'],
#  ['Moblin', 'Silver Moblin', 'Black Moblin'],
#  ['Lynel'],
#  ['Golden Bokoblin',
#   'Stalkoblin',
#   'Link',
#   'Blue Bokoblin',
#   'Black Bokoblin',
#   'Silver Bokoblin'],
#  ['Link', 'Fire Chuchu', 'Electric Chuchu', 'Ice Chuchu'],
#  ['Cursed Lizalfos', 'Cursed Moblin', 'Stalkoblin', 'Bokoblin', 'Link'],
#  ['Cursed Bokoblin', 'Stalizalfos', 'Cursed Moblin'],
#  ['Moblin', 'Cursed Bokoblin', 'Link', 'Stalmoblin'],
#  ['Guardian Skywatcher',
#   'Guardian Stalker',
#   'Guardian Turret',
#   'Link',
#   'Sentry'],
#  ['Fire Chuchu', 'Ice Chuchu', 'Chuchu'],
#  ['Fire Keese', 'Link'],
#  ['Lizalfos', 'Link'],
#  ['Electric Keese', 'Link', 'Electric Chuchu'],
#  ['Ice Chuchu', 'Link', 'Electric Chuchu', 'Chuchu'],
#  ['Ice Keese', 'Keese', 'Link', 'Electric Keese'],
#  ['Fire Chuchu', 'Fire Keese'],
#  ['Lizalfos', 'Link'],
#  ['Sky Octorok',
#   'Rock Octorok',
#   'Snow Octorok',
#   'Treasure Octorok',
#   'Link',
#   'Water Octorok'],
#  ['Igneo Pebblit', 'Frost Talus', 'Link', 'Stone Pebblit'],
#  ['Stalkoblin',
#   'Blue Bokoblin',
#   'Bokoblin',
#   'Black Bokoblin',
#   'Silver Bokoblin'],
#  ['Fire-Breath Lizalfos',
#   'Blue Lizalfos',
#   'Black Lizalfos',
#   'Stalizalfos',
#   'Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Silver Lizalfos',
#   'Electric Lizalfos'],
#  ['Lynel',
#   'Old Man',
#   'Blue-Maned Lynel',
#   'Link',
#   'Silver Lynel',
#   'White-Maned Lynel'],
#  ['Moblin', 'Bokoblin', 'Old Man', 'Link', 'Silver Moblin'],
#  ['Calamity Ganon'],
#  ['Guardian Scout I', 'Link'],
#  ['Guardian Turret', 'Guardian Scout II', 'Link'],
#  ['Link'],
#  ['Guardian Turret', 'Link', 'Calamity Ganon'],
#  ['Decayed Guardian',
#   'Guardian Skywatcher',
#   'Guardian Turret',
#   'Link',
#   'Sentry',
#   'Calamity Ganon'],
#  ['Decayed Guardian', 'Link', 'Calamity Ganon'],
#  ['Fire Chuchu', 'Electric Chuchu', 'Chuchu'],
#  ['Fire Keese', 'Keese', 'Electric Keese', 'Link'],
#  ['Ice Chuchu', 'Link', 'Ice Keese'],
#  ['Golden Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Stalizalfos',
#   'Lizalfos',
#   'Electric Lizalfos',
#   'Blue Lizalfos',
#   'Cursed Lizalfos',
#   'Black Lizalfos',
#   'Silver Lizalfos'],
#  ['Frost Pebblit', 'Link', 'Igneo Talus', 'Stone Pebblit'],
#  ['Fire Keese', 'Ice Keese', 'Electric Keese'],
#  ['Fire-Breath Lizalfos',
#   'Blue Lizalfos',
#   'Cursed Lizalfos',
#   'Moblin',
#   'Black Lizalfos',
#   'Stalizalfos',
#   'Link',
#   'Ice-Breath Lizalfos',
#   'Silver Lizalfos',
#   'Golden Lizalfos',
#   'Electric Lizalfos'],
#  ['Moblin',
#   'Silver Lynel',
#   'Golden Lynel',
#   'Princess Zelda',
#   'Kilton',
#   'Old Man',
#   'Blue-Maned Lynel',
#   'Link',
#   'White-Maned Lynel'],
#  ['Fire Chuchu', 'Fire Wizzrobe', 'Fire Keese'],
#  ['Golden Moblin',
#   'Hinox',
#   'Stalmoblin',
#   'Cursed Moblin',
#   'Lizalfos',
#   'Princess Zelda',
#   'Beedle',
#   'Old Man',
#   'Link',
#   'Bokoblin'],
#  ['Link'],
#  ['Guardian Skywatcher', 'Yunobo', 'Link'],
#  ['Golden Bokoblin',
#   'Stalkoblin',
#   'Bokoblin',
#   'Blue Bokoblin',
#   'Black Bokoblin'],
#  ['Fire-Breath Lizalfos',
#   'Blue Lizalfos',
#   'Cursed Lizalfos',
#   'Black Lizalfos',
#   'Stalizalfos',
#   'Lizalfos',
#   'Link',
#   'Ice-Breath Lizalfos',
#   'Golden Lizalfos',
#   'Electric Lizalfos',
#   'Calamity Ganon'],
#  ['Lynel', 'White-Maned Lynel'],
#  ['Moblin', 'Calamity Ganon', 'Golden Moblin', 'Black Moblin'],
#  ['Link'],
#  ['Sky Octorok',
#   'Rock Octorok',
#   'Forest Octorok',
#   'Link',
#   'Treasure Octorok',
#   'Water Octorok'],
#  ['Fire-Breath Lizalfos',
#   'Blue Lizalfos',
#   'Cursed Lizalfos',
#   'Stalmoblin',
#   'Black Lizalfos',
#   'Stalkoblin',
#   'Lizalfos',
#   'Link',
#   'Ice-Breath Lizalfos',
#   'Silver Lizalfos',
#   'Golden Lizalfos',
#   'Electric Lizalfos'],
#  ['Stalmoblin',
#   'Cursed Bokoblin',
#   'Golden Bokoblin',
#   'Stalizalfos',
#   'Bokoblin',
#   'Blue Bokoblin',
#   'Black Bokoblin',
#   'Silver Bokoblin'],
#  ['Moblin', 'Cursed Moblin', 'Link'],
#  ['Stone Talus', 'Link'],
#  ['Electric Keese', 'Link', 'Electric Wizzrobe', 'Electric Chuchu'],
#  ['Sky Octorok',
#   'Rock Octorok',
#   'Snow Octorok',
#   'Link',
#   'Forest Octorok',
#   'Water Octorok'],
#  ['Link'],
#  ['Bokoblin', 'Lynel', 'Blue-Maned Lynel'],
#  ['Link', 'Master Kohga'],
#  ['Yiga Blademaster',
#   'Monk Maz Koshia',
#   'Robbie',
#   'Princess Zelda',
#   'Purah',
#   'Link',
#   'Calamity Ganon',
#   'Master Kohga'],
#  ['Kilton', 'Stalnox', 'Link', 'Blue Hinox', 'Calamity Ganon', 'Hinox'],
#  ['Kilton',
#   'Stalnox',
#   'Black Hinox',
#   'Link',
#   'Calamity Ganon',
#   'Torfeau',
#   'Hinox'],
#  ['Windblight Ganon',
#   'Dark Beast Ganon',
#   'Thunderblight Ganon',
#   'Fireblight Ganon',
#   'Waterblight Ganon'],
#  ['Princess Zelda', 'Link', 'Calamity Ganon'],
#  ['Calamity Ganon',
#   'Waterblight Ganon',
#   'Thunderblight Ganon',
#   'Daruk',
#   'Windblight Ganon',
#   'Yunobo',
#   'Link'],
#  ['Kilton', 'Stone Talus', 'Link', 'Calamity Ganon'],
#  ['Link', 'Fire Keese', 'Stalnox', 'Bokoblin'],
#  ['Kilton', 'Fugo', 'Stone Talus', 'Link', 'Calamity Ganon'],
#  ['Igneo Talus',
#   'Daruk',
#   'Igneo Pebblit',
#   'Stone Talus',
#   'Frost Talus',
#   'Molduking'],
#  ['Link'],
#  ['Kilton', 'Molduking', 'Link'],
#  ['Igneo Talus Titan', 'Molduga', 'Traysi', 'Teake'],
#  ['Thunderblight Ganon', 'Link', 'Yiga Footsoldier'],
#  ['Kilton', 'Link', 'Hinox'],
#  ['Kilton',
#   'Stone Talus (Luminous)',
#   'Frost Talus',
#   'Link',
#   'Igneo Talus',
#   'Stone Talus (Rare)'],
#  ['Stone Talus'],
#  ['Kilton', 'Stone Talus', 'Stone Talus (Rare)', 'Calamity Ganon'],
#  ['Kilton', 'Stone Talus', 'Link', 'Calamity Ganon'],
#  ['Stone Talus'],
#  ['Calamity Ganon',
#   'Waterblight Ganon',
#   'Urbosa',
#   'Windblight Ganon',
#   'Link',
#   'Fireblight Ganon'],
#  ['Sidon', 'Mipha'],
#  ['Revali',
#   'Calamity Ganon',
#   'Fireblight Ganon',
#   'Waterblight Ganon',
#   'Thunderblight Ganon',
#   'Link']]

# %%
L_onelist = [y for x in links for y in x]
print(f'number of links found: {len(L_onelist)}')
# Out:
# number of links found: 1589

# %%
list_dict = {df.name.values[i]: x for i,x in enumerate(links) for y in x if (y in df.name.values)}
list_dict
# Out:
# {'Agus': ['Link'],
#  'Aji': ['Offrak', 'Fyson', 'Pelison'],
#  'Akrah': ['Garshon', 'Link', 'Zumi', 'Onya'],
#  'Aliza': ['Link'],
#  'Amali': ['Kheel', 'Notts', 'Kass', 'Kotts', 'Genli', 'Cree'],
#  'Ami': ['Izra', 'Link', 'Yolero'],
#  'Amira': ['Link', 'Azu', 'Pruce', 'Purah', 'Ivee', 'Nikki'],
#  'Anche': ['Furosa', 'Link', 'Pokki'],
#  'Anly': ['Link', 'Shay', 'Cima', 'Kampo'],
#  'Ardin': ['Jules', 'Spera', 'Nellie', 'Estan'],
#  'Ariane': ['Lester', 'Link', 'Galli'],
#  'Armes': ['Numar', 'Sebasto', 'Link'],
#  'Ashai': ['Dina', 'Link', 'Risa', 'Pasha'],
#  'Ashe': ['Link', 'Shamae', 'Kish', 'Breen'],
#  'Aster': ['Bolson', 'Link', 'Medda', 'Karin'],
#  'Aurie Taamu': ['Ashai', 'Isha'],
#  'Axyl': ['Dorill', 'Pelison'],
#  'Aya': ['Khini', 'Robbie', 'Rudi'],
#  'Azu': ['Sefaro', 'Amira', 'Link', 'Pruce', 'Purah', 'Ivee', 'Karin'],
#  'Babi': ['Link', 'Marta', 'Smaude', 'Teake', 'Malena'],
#  'Baddek': ['Savelle', 'Link', 'Yammo', 'Nazbi'],
#  'Bamboo': ['Baumar'],
#  'Banji': ['Ena',
#   'Konba',
#   'Sho',
#   'Geggle',
#   'Chork',
#   'Malanya',
#   'Kenyo',
#   'Hylia',
#   'Dabi'],
#  'Bargoh': ['Bludo', 'Link', 'Yunobo'],
#  'Barta': ['Link', 'Riju', 'Perda', 'Kotta', 'Liana', 'Leena'],
#  'Baumar': ['Selmie', 'Falmark', 'Bamboo'],
#  'Bayge': ['Kabetta', 'Heehl', 'Daruk'],
#  'Bazz': ['Link', 'Gaddison', 'Rivan', 'King Dorephan'],
#  'Bedoli': ['Link', 'Laissa'],
#  'Beedle': ['Link'],
#  'Benja': ['Link', 'Robsten', 'Vilia'],
#  'Benny': ['Link'],
#  'Bertri': ['Link', 'Riju'],
#  'Bladon': ['Gonguron'],
#  'Bludo': ['Yunobo', 'Kass', 'Daruk'],
#  'Blynne': ['Link'],
#  'Boldon': ['Naddon', 'Bolson', 'Link'],
#  'Bolson': ['Boldon', 'Link', 'Hudson', 'Karson'],
#  'Bozai': ['Link'],
#  'Branli': ['Link'],
#  'Breen': ['Epona'],
#  'Brigo': ['Decayed Guardian', 'Guardian Stalker', 'Link'],
#  'Brokka': ['Link'],
#  'Bugut': ['Link', 'Claree'],
#  'Buliara': ['Link', 'Riju', 'Princess Zelda', 'Teake'],
#  'Cado': ['Link', 'Impa', 'Dorian', 'Rola', 'Calamity Ganon'],
#  'Calisa': ['Link'],
#  'Calyban': ['Link', 'Dalia'],
#  'Cambo': ['Link'],
#  'Canni': ['Epona'],
#  'Canolo': ['Oliff',
#   'Link',
#   'Bokoblin',
#   'Blue Bokoblin',
#   'Palme',
#   'Flaxel',
#   'Sesami'],
#  'Cara': ['Link', 'Ashai', 'Isha'],
#  'Cecili': ['Link', 'Stalkoblin'],
#  'Celessa': ['Link', 'King Rhoam', 'Guardian Stalker', 'Impa'],
#  'Chaas Qeta': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Chabi': ['Link', 'Kilton', 'Bokoblin', 'Blue Bokoblin', 'Black Bokoblin'],
#  'Chessica': ['Link'],
#  'Chio': ['Hestu', 'Link'],
#  'Chork': ['Link', 'Kass', 'Geggle'],
#  'Chumin': ['Link'],
#  'Cima': ['Link'],
#  'Claree': ['Link', 'Nanna', 'Lasli'],
#  'Clavia': ['Link', 'Reede', 'Karin'],
#  'Cleff': ['Tona', 'Link'],
#  'Cloyne': ['Link', 'Armes'],
#  'Cotera': ['Kaysa', 'Link', 'Tera', 'Dorian'],
#  'Cottla': ['Link', 'Impa', 'Dorian', 'Koko'],
#  'Cree': ['Link',
#   'Genli',
#   'Kass',
#   'Kheel',
#   'Notts',
#   'Kotts',
#   'Amali',
#   'Kaneli'],
#  'Daag Chokah': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Dabi': ['Link'],
#  'Dagah Keek': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Dah Kaso': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Dai': ['Silver Lynel', 'Golden Lynel', 'Lynel'],
#  'Dalia': ['Lorn', 'Makure', 'Link', 'Kalani', 'Ashai', 'Pearle'],
#  'Damia': ['Link'],
#  'Danda': ['Makure', 'Link', 'Kalani'],
#  'Dantz': ['Link'],
#  'Darton': ['Sagessa', 'Link', 'Tasseren', 'Rensa', 'Shibo'],
#  'Daruk': ['Link',
#   'King Rhoam',
#   'Yunobo',
#   'Bokoblin',
#   'Revali',
#   'Princess Zelda',
#   'Calamity Ganon',
#   'Dark Beast Ganon',
#   'Fireblight Ganon',
#   'Bludo'],
#  'Dauntless': ['Nazbi'],
#  'Dayto': ['Guardian Stalker'],
#  'Daz': ['Link'],
#  'Deltan': ['Link', 'Ashai'],
#  'Dento': ['Mipha', 'Marot', 'Link'],
#  'Dila Maag': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Dillie': ['Link', 'Bokoblin', 'Jora'],
#  'Dina': ['Link', 'Ashai'],
#  'Dinraal': ['Farosh', 'Naydra'],
#  'Dmitri': ['Kaifa', 'Jana', 'Link', 'Gleema'],
#  'Domidak': ['Link', 'Misko', 'Prissen'],
#  'Dorian': ['Link',
#   'Yiga Blademaster',
#   'Lasli',
#   'Impa',
#   'Paya',
#   'Cotera',
#   'Mellie',
#   'Cado',
#   'Koko',
#   'Cottla'],
#  'Dorill': ['Bludo', 'Axyl'],
#  'Dorrah': ['Link', 'Merina', 'Riju'],
#  'Douma': ['Mipha', 'Link', 'Sidon'],
#  'Drak': ['Bludo', 'Link', 'Yunobo'],
#  'Dugby': ['Link', 'Grapp'],
#  'Dunma': ['Mipha',
#   'Link',
#   'Rivan',
#   'Dunma',
#   'King Dorephan',
#   'Sidon',
#   'Trello'],
#  'Eighth Heroine': ['Link', 'Seven Heroines', 'Bozai'],
#  'Emri': ['Link', 'Vilia'],
#  'Ena': ['Hestu', 'Link', 'Kenyo', 'Banji'],
#  'Epona': ['Link', 'Malanya'],
#  'Eryck': ['Gruve'],
#  'Essa': ['Frelly', 'Link'],
#  'Estan': ['Link', 'Frita', 'Maike'],
#  'Etsu Korima': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Farosh': ['Link', 'Naydra', 'Dinraal'],
#  'Fegran': ['Link', 'Riju'],
#  'Fin': ['Russ'],
#  'Finley': ['Link', 'Kayden', 'Kodah', 'Sidon'],
#  'Frelly': ['Link', 'Kohm'],
#  'Frita': ['Link'],
#  'Fronk': ['Mei', 'Link', 'Keye', 'Tumbo', 'Dento'],
#  'Fugo': ['Slergo', 'Igneo Talus', 'Rohan'],
#  'Furosa': ['Link', 'Anche', 'Pokki', 'Greta'],
#  'Fyson': ['Link', 'Hudson', 'Misa'],
#  'Gaddison': ['Rivan', 'Bazz'],
#  'Garill': ['Guardian Stalker', 'Link'],
#  'Gartan': ['Link'],
#  'Gleema': ['Dmitri', 'Kaifa', 'Jana'],
#  'Glendo': ['Link', 'Keese'],
#  'Goma Asaagh': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Gonguron': ['Bladon'],
#  'Gorae Torr': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Gotter': ['Princess Zelda', 'Hinox'],
#  'Granté': ['Bludo', 'Dugby'],
#  'Grapp': ['Link'],
#  'Greta': ['Bolson',
#   'Rhondson',
#   'Hudson',
#   'Dorill',
#   'Axyl',
#   'Jengo',
#   'Bohrin',
#   'Pelison'],
#  'Greyson': ['Link', 'King Dorephan', 'Sidon', 'Lynel'],
#  'Gruve': ['Link'],
#  'Ha Dahamar': ['Ruli', 'Hunnie'],
#  'Hagie': ['Link', 'Myti'],
#  'Haite': ['Link', 'Danton'],
#  'Harlow': ['Monkton', 'Mary (Breath of the Wild)'],
#  'Harry (Breath of the Wild)': ['Link',
#   'Teba',
#   'Kaneli',
#   'Revali',
#   'Calamity Ganon',
#   'Molli'],
#  'Hawa Koth': ['Kabetta', 'Bayge'],
#  'Heehl': ['Link'],
#  'Hestu': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Hila Rao': ['Link'],
#  'Hino': ['Hylia', 'Teebo'],
#  'Horned Statue': ['Kilton'],
#  'Hoz': ['Revali', 'Verla'],
#  'Huck': ['Bolson', 'Link', 'Rhondson'],
#  'Hudson': ['Hagie', 'Ruli'],
#  'Hunnie': ['Princess Zelda', 'Impa'],
#  'Hylia': ['Bokoblin',
#   'Link',
#   'King Rhoam',
#   'Purah',
#   'Princess Zelda',
#   'Paya',
#   'Hylia',
#   'Fire Wizzrobe',
#   'Calamity Ganon'],
#  'Impa': ['Link', 'Cara'],
#  'Ishto Soh': ['Amira', 'Link', 'Azu', 'Pruce'],
#  'Ja Baij': ['Kaifa', 'Link', 'Gleema', 'Hudson', 'Dmitri'],
#  'Jee Noh': ['Bludo', 'Greyson', 'Dorill', 'Bohrin'],
#  'Jengo': ['Link', 'Nanna', 'Purah', 'Symin', 'Robbie'],
#  'Jerrin': ['Mipha'],
#  'Jiahto': ['Link'],
#  'Jini': ['Link', 'Calamity Ganon', 'Hylia'],
#  "Jitan Sa'mi": ['Juney'],
#  'Joloo Nah': ['Link', 'Bokoblin', 'Dillie'],
#  'Jora': ['Link'],
#  'Juannelle': ['Link'],
#  'Jules': ['Jogo'],
#  "Kaam Ya'tak": ['Bayge', 'Heehl'],
#  'Kabetta': ['Link'],
#  'Kachoo': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Kah Yah': ['Dmitri', 'Jana', 'Gleema'],
#  'Kaifa': ['Yunobo'],
#  'Kairo': ['Makure', 'Frita', 'Dalia', 'Danda', 'Ashai', 'Pearle'],
#  'Kampo': ['Teba'],
#  'Kanny': ['Mipha', 'Link', 'Hudson', 'Hylia', 'Rhondson'],
#  'Kapson': ['Reede', 'Clavia'],
#  'Karsh': ['Sophie', 'Bolson', 'Link'],
#  'Karson': ['Genli',
#   'Farosh',
#   'Cree',
#   'Kheel',
#   'Princess Zelda',
#   'Notts',
#   'Kotts',
#   'Amali'],
#  'Kass': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Katah Chuki': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Katosa Aug': ['Link', 'Riju'],
#  'Kaya Wan': ['Link', 'Finley', 'Kodah'],
#  'Kayra Mah': ['Tera', 'Cotera', 'Toren'],
#  'Kaysa': ['Link', 'Calamity Ganon', 'Hylia'],
#  "Ke'nai Shakah": ['Link', 'Calamity Ganon', 'Hylia'],
#  'Keh Namut': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Keive Tala': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Kema Zoos': ['Link'],
#  'Keo Ruug': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Ketoh Wawai': ['Mipha', 'Mei', 'Link', 'Tumbo', 'Fronk'],
#  'Keye': ['Link',
#   'Genli',
#   'Kass',
#   'Cree',
#   'Notts',
#   'Kotts',
#   'Amali',
#   'Kaneli'],
#  'Khini': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Kiana': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Kihiro Moh': ['Link', 'Hoz', 'Calamity Ganon'],
#  'Kima': ['Mipha', 'Princess Zelda', 'Link', 'Muzu'],
#  'King Dorephan': ['Link',
#   'Old Man',
#   'Princess Zelda',
#   'Impa',
#   'Calamity Ganon'],
#  'King Rhoam': ['Link', 'Kiana'],
#  'Kinov': ['Link'],
#  'Kish': ['Mipha', 'Link', 'Finley', 'Kayden', 'Sidon', 'King Dorephan'],
#  'Kodah': ['Frelly', 'Link'],
#  'Kohm': ['Link', 'Dorian', 'Cottla'],
#  'Koko': ['Link'],
#  'Konba': ['Link'],
#  'Konora': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Korgu Chideh': ['Link', 'Calamity Ganon', 'Hylia'],
#  "Korsh O'hu": ['Barta', 'Link', 'Liana'],
#  'Kotts': ['Link', 'Dantz'],
#  'Koyin': ['Bludo'],
#  'Kuh Takkar': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Kuhn Sidajj': ['The Great Deku Tree', 'Kula'],
#  'Kula': ['Link'],
#  'Kyra': ['Mipha', 'Lynel', 'King Dorephan'],
#  'Laflat': ['Link', 'Tali'],
#  'Laissa': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Lakna Rokee': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Laroba': ['Tona',
#   'Mipha',
#   'Link',
#   'Trello',
#   'Tula',
#   'Sidon',
#   'King Dorephan'],
#  'Laruta': ['Link', 'Riju'],
#  'Lashley': ['Link', 'Claree', 'Nanna'],
#  'Lawdon': ['Link', 'Sidon', 'Dento'],
#  'Leekah': ['Barta', 'Link', 'Kotta', 'Riju', 'Liana'],
#  'Leena': ['Prima', 'Purah'],
#  'Leop': ['Link'],
#  'Letty': ['Barta', 'Link', 'Kotta', 'Riju', 'Leena'],
#  'Liana': ['King Rhoam',
#   'Princess Zelda',
#   'Impa',
#   'Kass',
#   'Old Man',
#   'Paya',
#   'Hylia',
#   'Calamity Ganon',
#   'Epona'],
#  'Link': ['Stalnox'],
#  'Lonni': ['Roscoe', 'Link'],
#  'Loone': ['Link', 'Dalia'],
#  'Lorn': ['Link', 'Riju'],
#  'Lukan': ['Strade'],
#  'Lyndae': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Maag Halan': ['Link', 'Calamity Ganon', 'Hylia'],
#  "Maag No'rah": ['Link'],
#  'Magda': ['Link', 'Vilia', 'Estan'],
#  'Maka Rah': ['Dalia', 'Kalani', 'Danda', 'Ashai', 'Pearle'],
#  'Makure': ['Link'],
#  'Malanya': ['Link', 'Molduga'],
#  'Malena': ['Link'],
#  'Manny (Breath of the Wild)': ['Link', 'Dento'],
#  'Marot': ['Babi', 'Link', 'Riju'],
#  'Marta': ['Harry (Breath of the Wild)', 'Monkton'],
#  'Mary (Breath of the Wild)': ['Link'],
#  'Maypin': ['Ozunda'],
#  'Mayro': ['Link'],
#  'Mazli': ['Princess Zelda', 'Link', 'Aster'],
#  'Meeshy': ['Bokoblin', 'Nat'],
#  'Meghyn': ['Link', 'Tumbo', 'Fronk', 'Keye'],
#  'Mei': ['Steen', 'Olkin'],
#  'Mellie': ['Link', 'Dorrah'],
#  'Mezza Lo': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Mijah Rokee': ['Mina'],
#  'Mils': ['Link'],
#  'Mimos': ['Link', 'Mils'],
#  'Mina': ['Link',
#   'King Rhoam',
#   'King Dorephan',
#   'Sidon',
#   'Princess Zelda',
#   'Muzu',
#   'Waterblight Ganon'],
#  'Misa': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Misae Suma': ['Link', 'Domidak', 'Prissen'],
#  'Mogg Latan': ['Monari'],
#  'Moggs': ['Harth'],
#  'Molo': ['Moggs'],
#  'Monari': ['Link'],
#  'Monya Toma': ['Link'],
#  'Moza': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Mozo Shenno': ['Link'],
#  'Mubs': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Muwo Jeem': ['Mipha', 'Link', 'Sidon', 'King Dorephan'],
#  'Myahm Agana': ['Trott', 'Link', 'Haite'],
#  'Myti': ['Link', 'Sayge'],
#  'Nack': ['Boldon'],
#  'Naddon': ['Link', 'Riju', 'Pritana', 'Urbosa'],
#  'Nali': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Namika Ozz': ['Impa',
#   'Jerrin',
#   'Claree',
#   'Purah',
#   'Lasli',
#   'Symin',
#   'Robbie'],
#  'Nanna': ['Amira', 'Link', 'Nack', 'Nebb', 'Nikki'],
#  'Narah': ['Meghyn', 'Bokoblin'],
#  'Nat': ['Link'],
#  'Natie': ['Link', 'Farosh', 'Dinraal'],
#  "Ne'ez Yohma": ['Link', 'Nack', 'Nikki', 'Narah'],
#  'Nekk': ['Link', 'Blue Moblin'],
#  'Nell': ['Lorn', 'Link', 'Risa', 'Ardin'],
#  'Nellie': ['Amira', 'Link', 'Purah', 'Nebb', 'Nack', 'Narah'],
#  'Nikki': ['Link'],
#  'Nobiro': ['Link', 'Pitar'],
#  'Nobo': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Notts': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Oaki': ['Aji'],
#  'Offrak': ['Link', 'Princess Zelda', 'Calamity Ganon'],
#  'Old Man': ['Link', 'Sesami'],
#  'Oliff': ['Link', 'Mellie'],
#  'Olkin': ['Link', 'Olkin', 'Mellie'],
#  'Ollie': ['Link', 'Romah'],
#  'Owa Daim': ['Link'],
#  'Ozunda': ['Link', 'Riju', 'Patricia'],
#  'Padda': ['Link'],
#  'Parcy': ['Ashai', 'Link'],
#  'Pasha': ['Padda', 'Link', 'Riju'],
#  'Patricia': ['Link', 'Dorian', 'Purah', 'Princess Zelda', 'Impa', 'Cado'],
#  'Paya': ['Makure', 'Link', 'Spera', 'Kalani', 'Ashai', 'Rotana', 'Urbosa'],
#  'Pearle': ['The Great Deku Tree', 'Link'],
#  'Peeks': ['Greyson', 'Bolson', 'Hudson', 'Axyl', 'Rhondson'],
#  'Pelison': ['Link'],
#  'Pepp': ['Barta', 'Wabbin', 'Ashai', 'Pyra', 'Sumati', 'Yaido'],
#  'Phanna': ['Link'],
#  'Piaffe': ['Link', 'Impa', 'Master Kohga'],
#  'Pikango': ['Link'],
#  'Pitar': ['Traysi', 'Link', 'Riju', 'Reeza'],
#  'Ploka': ['Furosa', 'Link'],
#  'Pokki': ['Link'],
#  'Ponthos': ['Manny (Breath of the Wild)', 'Link'],
#  'Prima': ['Link',
#   'King Rhoam',
#   'Impa',
#   'Yiga Footsoldier',
#   'Kass',
#   'Daruk',
#   'Hylia'],
#  'Princess Zelda': ['Link', 'Domidak', 'Misko'],
#  'Prissen': ['Nali', 'Link', 'Riju', 'Urbosa'],
#  'Pritana': ['Amira', 'Link', 'Azu', 'Ivee'],
#  'Pruce': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Pumaag Nitae': ['Monk Maz Koshia',
#   'Princess Zelda',
#   'Impa',
#   'Paya',
#   'Symin',
#   'Calamity Ganon',
#   'Robbie'],
#  'Purah': ['Bludo', 'Rogaro'],
#  'Pyle': ['Perda', 'Rotana', 'Saula', 'Sumati', 'Yaido'],
#  'Pyra': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Qua Raym': ['Satty'],
#  'Quince': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Qukah Nata': ['Link', 'Purah', 'Rhodes', 'Rozel'],
#  'Ralera': ['Offrak', 'Calamity Ganon'],
#  'Ramella': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Raqa Zunzo': ['Link', 'Sidon'],
#  'Ree Dahee': ['Link', 'Purah', 'Clavia', 'Karin'],
#  'Reede': ['Link', 'Buliara', 'Riju', 'Ploka'],
#  'Regan': ['Link', 'Darton', 'Purah', 'Tasseren', 'Shibo'],
#  'Rensa': ['Link',
#   'King Rhoam',
#   'Princess Zelda',
#   'Daruk',
#   'Urbosa',
#   'Windblight Ganon'],
#  'Rex': ['Link', 'Ralera'],
#  'Rhodes': ['Link', 'Hudson'],
#  'Rhondson': ['Link', 'Urbosa', 'Buliara', 'Teake', 'Patricia'],
#  'Riju': ['Steen', 'Olkin'],
#  'Rik': ['Link', 'Buliara', 'Riju', 'Patricia'],
#  'Rin Oyaa': ['Link', 'Vilia'],
#  'Ripp': ['Dina', 'Link', 'Nellie', 'Ashai', 'Pasha'],
#  'Risa': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Ritaag Zumo': ['Link', 'Gaddison', 'Dunma', 'Bazz', 'Trello'],
#  'Rivan': ['Link', 'Purah', 'Princess Zelda', 'Jerrin', 'Calamity Ganon'],
#  'Robbie': ['Link', 'Benja', 'Vilia'],
#  'Robsten': ['Pyle'],
#  'Rogaro': ['Slergo', 'Fugo', 'Igneo Talus'],
#  'Rohan': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Rok Uwog': ['Link', 'Cado'],
#  'Rola': ['Link'],
#  'Romah': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Ronn': ['Link'],
#  'Rota Ooh': ['Link', 'Seven Heroines', 'Pearle', 'Urbosa'],
#  'Rotana': ['Ralera'],
#  'Rudi': ['Hagie', 'Hunnie'],
#  'Ruli': ['Fin'],
#  'Russ': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Ruvo Korbah': ['Link', 'Calamity Ganon', 'Hylia'],
#  "Saas Ko'sah": ['Link', 'Darton', 'Shibo'],
#  'Sah Dahaj': ['Link', 'Teba', 'Kaneli', 'Revali', 'Tulin'],
#  'Saki': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Sasa Kai': ['Quince', 'Link', 'Satty'],
#  'Satty': ['Link', 'Yaido'],
#  'Savelle': ['Sefaro', 'Senna'],
#  'Sebasto': ['Link', 'Azu', 'Purah', 'Sayge', 'Senna'],
#  'Sefaro': ['Mipha', 'Link'],
#  'Seggin': ['Sophie', 'Link', 'Sayge'],
#  'Selmie': ['Sefaro', 'Sayge'],
#  'Senna': ['Oliff', 'Link', 'Palme', 'Flaxel', 'Canolo'],
#  'Sesami': ['Link', 'Eighth Heroine', 'Rotana'],
#  'Sha Warvo': ['Link', 'Tali'],
#  'Shada Naw': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Shai Utoh': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Shai Yota': ['Link', 'Vilia'],
#  'Shaillu': ['Ashe'],
#  'Sherfin': ['Link', 'Darton', 'Tasseren', 'Rensa'],
#  'Shibo': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Shoda Sah': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Shora Hah': ['Mipha', 'Link', 'King Dorephan', 'Muzu', 'Calamity Ganon'],
#  'Sidon': ['Rohan', 'Fugo'],
#  'Slergo': ['Link'],
#  'Smaude': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Soh Kofi': ['Link', 'Seldon', 'Karson'],
#  'Sorelia': ['Link'],
#  'Spera': ['Spinch (Hylian)'],
#  'Spinch (Hylian)': ['Naydra', 'Link'],
#  'Stamm': ['Link', 'Olkin', 'Trissa', 'Calamity Ganon'],
#  'Steen': ['Link', 'Lyndae'],
#  'Straia': ['Link', 'Riju'],
#  'Sudrey': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Suma Sahma': ['Perda', 'Pyra', 'Rotana', 'Saula', 'Yaido'],
#  'Suzuna': ['Link', 'Impa', 'Purah', 'Calamity Ganon'],
#  'Tah Muhl': ['Link', 'Calamity Ganon', 'Hylia'],
#  "Tahno O'ah": ['Link', 'Calamity Ganon', 'Hylia'],
#  'Takama Shiri': ['Teli', 'Shabonne'],
#  'Tali': ['Link'],
#  'Tasho': ['Link', 'Rensa'],
#  'Tasseren': ['Link'],
#  'Tauma': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Tawa Jinn': ['Link', 'Buliara', 'Riju'],
#  'Teake': ['Windblight Ganon',
#   'Link',
#   'Saki',
#   'Revali',
#   'Calamity Ganon',
#   'Harth',
#   'Tulin'],
#  'Teba': ['Horned Statue', 'Link', 'Reede'],
#  'Teebo': ['Link', 'Tali', 'Bokoblin', 'Calamity Ganon', 'Robbie'],
#  'Teli': ['Link', 'Calamity Ganon', 'Hylia'],
#  "Tena Ko'sah": ['Kaifa', 'Jana', 'Epona', 'Link', 'Gleema', 'Dmitri'],
#  'Tenne': ['Kaysa', 'Link', 'Cotera'],
#  'Tera': ['Link', 'Seldon'],
#  'Thadd': ['Link', 'Princess Zelda'],
#  'The Great Deku Tree': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Tho Kayu': ['Link', 'Calamity Ganon', 'Hylia'],
#  'To Quomo': ['Link', 'Princess Zelda'],
#  'Toh Yahsa': ['Link', 'Purah', 'Uma'],
#  'Toma': ['Link', 'Laruta', 'Tula', 'Sidon', 'Cleff'],
#  'Tona': ['Kaysa'],
#  'Toren': ['Sidon', 'Hinox'],
#  'Tottika': ['Volcon'],
#  'Tray': ['Link',
#   'Muava',
#   'King Rhoam',
#   'Riju',
#   'Strade',
#   'Ploka',
#   'Farosh',
#   'Naydra',
#   'Lyndae',
#   'Princess Zelda',
#   'Molduking',
#   'Ashai',
#   'Molduga',
#   'Dinraal'],
#  'Traysi': ['Mipha', 'Link', 'Dento', 'Rivan', 'Dunma'],
#  'Trello': ['Steen', 'Olkin'],
#  'Trott': ['Link', 'Calamity Ganon', 'Hylia'],
#  "Tu Ka'loh": ['Link', 'King Dorephan', 'Waterblight Ganon', 'Sidon'],
#  'Tula': ['Link', 'Teba', 'Saki'],
#  'Tulin': ['Mipha', 'Mei', 'Link', 'Calamity Ganon', 'Keye', 'Fronk'],
#  'Tumbo': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Tye': ['Link', 'Calamity Ganon'],
#  'Uma': ['King Rhoam',
#   'Thunderblight Ganon',
#   'Riju',
#   'Kass',
#   'Revali',
#   'Princess Zelda',
#   'Calamity Ganon',
#   'Yiga Footsoldier',
#   'Pearle'],
#  'Verla': ['Link', 'Riju', 'Benja'],
#  'Vilia': ['Tray'],
#  'Voo Lota': ['Wabbin', 'Perda'],
#  'Wahgo Katta': ['Link'],
#  'Yah Rin': ['Pyra', 'Rotana', 'Saula', 'Sumati', 'Perda'],
#  'Yolero': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Yowaka Ita': ['Bludo',
#   'Link',
#   'Fireblight Ganon',
#   'Daruk',
#   'Black Moblin',
#   'Sentry'],
#  'Zalta Wa': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Zumi': ['Link', 'Calamity Ganon', 'Hylia'],
#  'Zuta': ['Link'],
#  'Zyle': ['Blue Bokoblin'],
#  'Black Bokoblin': ['Lizalfos',
#   'Blue Lizalfos',
#   'Golden Lizalfos',
#   'Silver Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Electric Lizalfos',
#   'Stalizalfos',
#   'Fire-Breath Lizalfos'],
#  'Black Lizalfos': ['Blue Moblin'],
#  'Black Moblin': ['Ice Wizzrobe', 'Ice Chuchu', 'Ice Keese'],
#  'Blizzrobe': ['Link', 'White-Maned Lynel', 'Bokoblin', 'Blue Bokoblin'],
#  'Blue Bokoblin': ['Lizalfos',
#   'Golden Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Silver Lizalfos',
#   'Electric Lizalfos',
#   'Stalizalfos',
#   'Black Lizalfos',
#   'Cursed Lizalfos',
#   'Fire-Breath Lizalfos'],
#  'Blue Lizalfos': ['Silver Moblin', 'Black Moblin', 'Moblin'],
#  'Blue Moblin': ['Lynel'],
#  'Blue-Maned Lynel': ['Link',
#   'Golden Bokoblin',
#   'Silver Bokoblin',
#   'Blue Bokoblin',
#   'Black Bokoblin',
#   'Stalkoblin'],
#  'Bokoblin': ['Ice Chuchu', 'Fire Chuchu', 'Link', 'Electric Chuchu'],
#  'Chuchu': ['Link',
#   'Bokoblin',
#   'Cursed Lizalfos',
#   'Stalkoblin',
#   'Cursed Moblin'],
#  'Cursed Bokoblin': ['Cursed Moblin', 'Stalizalfos', 'Cursed Bokoblin'],
#  'Cursed Lizalfos': ['Moblin', 'Link', 'Cursed Bokoblin', 'Stalmoblin'],
#  'Cursed Moblin': ['Link',
#   'Guardian Stalker',
#   'Guardian Turret',
#   'Sentry',
#   'Guardian Skywatcher'],
#  'Decayed Guardian': ['Chuchu', 'Ice Chuchu', 'Fire Chuchu'],
#  'Electric Chuchu': ['Link', 'Fire Keese'],
#  'Electric Keese': ['Lizalfos', 'Link'],
#  'Electric Lizalfos': ['Link', 'Electric Chuchu', 'Electric Keese'],
#  'Electric Wizzrobe': ['Electric Chuchu', 'Link', 'Chuchu', 'Ice Chuchu'],
#  'Fire Chuchu': ['Link', 'Keese', 'Ice Keese', 'Electric Keese'],
#  'Fire Keese': ['Fire Keese', 'Fire Chuchu'],
#  'Fire Wizzrobe': ['Lizalfos', 'Link'],
#  'Fire-Breath Lizalfos': ['Snow Octorok',
#   'Sky Octorok',
#   'Link',
#   'Rock Octorok',
#   'Treasure Octorok',
#   'Water Octorok'],
#  'Forest Octorok': ['Link', 'Stone Pebblit', 'Igneo Pebblit', 'Frost Talus'],
#  'Frost Pebblit': ['Silver Bokoblin',
#   'Stalkoblin',
#   'Blue Bokoblin',
#   'Bokoblin',
#   'Black Bokoblin'],
#  'Golden Bokoblin': ['Lizalfos',
#   'Black Lizalfos',
#   'Silver Lizalfos',
#   'Electric Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Blue Lizalfos',
#   'Stalizalfos'],
#  'Golden Lizalfos': ['Blue-Maned Lynel',
#   'Link',
#   'White-Maned Lynel',
#   'Lynel',
#   'Old Man',
#   'Silver Lynel'],
#  'Golden Lynel': ['Silver Moblin', 'Link', 'Bokoblin', 'Old Man', 'Moblin'],
#  'Golden Moblin': ['Calamity Ganon'],
#  'Guardian Scout I': ['Link', 'Guardian Scout I'],
#  'Guardian Scout II': ['Link', 'Guardian Turret', 'Guardian Scout II'],
#  'Guardian Scout III': ['Link'],
#  'Guardian Scout IV': ['Link', 'Guardian Turret', 'Calamity Ganon'],
#  'Guardian Skywatcher': ['Link',
#   'Guardian Turret',
#   'Sentry',
#   'Decayed Guardian',
#   'Calamity Ganon',
#   'Guardian Skywatcher'],
#  'Guardian Stalker': ['Link', 'Decayed Guardian', 'Calamity Ganon'],
#  'Guardian Turret': ['Chuchu', 'Electric Chuchu', 'Fire Chuchu'],
#  'Ice Chuchu': ['Link', 'Keese', 'Fire Keese', 'Electric Keese'],
#  'Ice Keese': ['Link', 'Ice Chuchu', 'Ice Keese'],
#  'Ice Wizzrobe': ['Lizalfos',
#   'Blue Lizalfos',
#   'Golden Lizalfos',
#   'Electric Lizalfos',
#   'Silver Lizalfos',
#   'Stalizalfos',
#   'Black Lizalfos',
#   'Cursed Lizalfos',
#   'Fire-Breath Lizalfos'],
#  'Ice-Breath Lizalfos': ['Link',
#   'Stone Pebblit',
#   'Frost Pebblit',
#   'Igneo Talus'],
#  'Igneo Pebblit': ['Fire Keese', 'Ice Keese', 'Electric Keese'],
#  'Keese': ['Golden Lizalfos',
#   'Link',
#   'Black Lizalfos',
#   'Silver Lizalfos',
#   'Electric Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Cursed Lizalfos',
#   'Moblin',
#   'Blue Lizalfos',
#   'Stalizalfos'],
#  'Lizalfos': ['Kilton',
#   'Link',
#   'Princess Zelda',
#   'Moblin',
#   'Blue-Maned Lynel',
#   'Golden Lynel',
#   'White-Maned Lynel',
#   'Old Man',
#   'Silver Lynel'],
#  'Lynel': ['Fire Keese', 'Fire Wizzrobe', 'Fire Chuchu'],
#  'Meteo Wizzrobe': ['Bokoblin',
#   'Lizalfos',
#   'Link',
#   'Princess Zelda',
#   'Stalmoblin',
#   'Cursed Moblin',
#   'Golden Moblin',
#   'Old Man',
#   'Hinox',
#   'Beedle'],
#  'Moblin': ['Link'],
#  'Rock Octorok': ['Link', 'Yunobo', 'Guardian Skywatcher'],
#  'Sentry': ['Golden Bokoblin',
#   'Bokoblin',
#   'Blue Bokoblin',
#   'Black Bokoblin',
#   'Stalkoblin'],
#  'Silver Bokoblin': ['Lizalfos',
#   'Golden Lizalfos',
#   'Link',
#   'Black Lizalfos',
#   'Electric Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Calamity Ganon',
#   'Cursed Lizalfos',
#   'Blue Lizalfos',
#   'Stalizalfos'],
#  'Silver Lizalfos': ['White-Maned Lynel', 'Lynel'],
#  'Silver Lynel': ['Calamity Ganon', 'Golden Moblin', 'Black Moblin', 'Moblin'],
#  'Silver Moblin': ['Link'],
#  'Sky Octorok': ['Link',
#   'Rock Octorok',
#   'Forest Octorok',
#   'Treasure Octorok',
#   'Sky Octorok',
#   'Water Octorok'],
#  'Snow Octorok': ['Lizalfos',
#   'Golden Lizalfos',
#   'Link',
#   'Black Lizalfos',
#   'Silver Lizalfos',
#   'Electric Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Cursed Lizalfos',
#   'Stalkoblin',
#   'Stalmoblin',
#   'Blue Lizalfos'],
#  'Stalizalfos': ['Golden Bokoblin',
#   'Cursed Bokoblin',
#   'Bokoblin',
#   'Silver Bokoblin',
#   'Blue Bokoblin',
#   'Black Bokoblin',
#   'Stalmoblin',
#   'Stalizalfos'],
#  'Stalkoblin': ['Link', 'Cursed Moblin', 'Moblin'],
#  'Stalmoblin': ['Link', 'Stone Talus'],
#  'Stone Pebblit': ['Link',
#   'Electric Keese',
#   'Electric Chuchu',
#   'Electric Wizzrobe'],
#  'Thunder Wizzrobe': ['Snow Octorok',
#   'Link',
#   'Rock Octorok',
#   'Forest Octorok',
#   'Sky Octorok',
#   'Water Octorok'],
#  'Treasure Octorok': ['Link'],
#  'Water Octorok': ['Blue-Maned Lynel', 'Bokoblin', 'Lynel'],
#  'White-Maned Lynel': ['Link', 'Master Kohga'],
#  'Yiga Blademaster': ['Link',
#   'Yiga Blademaster',
#   'Purah',
#   'Monk Maz Koshia',
#   'Princess Zelda',
#   'Calamity Ganon',
#   'Robbie',
#   'Master Kohga'],
#  'Yiga Footsoldier': ['Link',
#   'Kilton',
#   'Stalnox',
#   'Calamity Ganon',
#   'Hinox',
#   'Blue Hinox'],
#  'Black Hinox': ['Link',
#   'Kilton',
#   'Torfeau',
#   'Stalnox',
#   'Calamity Ganon',
#   'Hinox',
#   'Black Hinox'],
#  'Blue Hinox': ['Thunderblight Ganon',
#   'Dark Beast Ganon',
#   'Fireblight Ganon',
#   'Windblight Ganon',
#   'Waterblight Ganon'],
#  'Calamity Ganon': ['Link', 'Princess Zelda', 'Calamity Ganon'],
#  'Dark Beast Ganon': ['Windblight Ganon',
#   'Link',
#   'Thunderblight Ganon',
#   'Yunobo',
#   'Calamity Ganon',
#   'Daruk',
#   'Waterblight Ganon'],
#  'Fireblight Ganon': ['Link', 'Kilton', 'Calamity Ganon', 'Stone Talus'],
#  'Frost Talus': ['Fire Keese', 'Bokoblin', 'Link', 'Stalnox'],
#  'Hinox': ['Link', 'Kilton', 'Fugo', 'Calamity Ganon', 'Stone Talus'],
#  'Igneo Talus': ['Stone Talus',
#   'Molduking',
#   'Daruk',
#   'Igneo Pebblit',
#   'Igneo Talus',
#   'Frost Talus'],
#  'Igneo Talus Titan': ['Link'],
#  'Master Kohga': ['Link', 'Kilton', 'Molduking'],
#  'Molduga': ['Traysi', 'Igneo Talus Titan', 'Molduga', 'Teake'],
#  'Molduking': ['Link', 'Thunderblight Ganon', 'Yiga Footsoldier'],
#  'Monk Maz Koshia': ['Link', 'Kilton', 'Hinox'],
#  'Stalnox': ['Link',
#   'Kilton',
#   'Stone Talus (Luminous)',
#   'Igneo Talus',
#   'Stone Talus (Rare)',
#   'Frost Talus'],
#  'Stone Talus': ['Stone Talus'],
#  'Stone Talus (Junior)': ['Kilton',
#   'Calamity Ganon',
#   'Stone Talus',
#   'Stone Talus (Rare)'],
#  'Stone Talus (Luminous)': ['Link', 'Kilton', 'Calamity Ganon', 'Stone Talus'],
#  'Stone Talus (Rare)': ['Stone Talus'],
#  'Stone Talus (Senior)': ['Windblight Ganon',
#   'Link',
#   'Calamity Ganon',
#   'Waterblight Ganon',
#   'Fireblight Ganon',
#   'Urbosa'],
#  'Thunderblight Ganon': ['Mipha', 'Sidon'],
#  'Waterblight Ganon': ['Link',
#   'Fireblight Ganon',
#   'Thunderblight Ganon',
#   'Calamity Ganon',
#   'Revali',
#   'Waterblight Ganon']}

# %%
import networkx as nx
G = nx.DiGraph()
nodes_with_attributes = [(df_a.Name[i],{'Role':df_a.Role[i],'Race':df_a.Race[i],'Gender':df_a.Gender[i]}) for i in df_a.index]
G.add_nodes_from([x for x in df.name.values])
G.add_edges_from([(x,i) for x in list_dict for i in list_dict[x]])
print(f'num nodes: {G.number_of_nodes()}')
print(f'num edges: {G.number_of_edges()}')
# Out:
# num nodes: 656
# num edges: 1589

# %%
nx.draw_spring(G,node_size=10,node_color='magenta')

# %%
# Remove isolated nodes from the network
G.remove_nodes_from(list(nx.isolates(G)))

# %% [markdown]
# > *Exercise 2*: Simple network statistics and analysis
# >
# > * What is the number of nodes in the network?
# > * More importantly, what is the number of links?
# > * Plot the distributions of Role, Race, and Gender.
# > * Plot the total (in+out), in and out-degree distributions. What do you observe? Can you explain why the in-degree distribution is different from the out-degree distribution?
# >     * Compare the degree distribution to a *random network* with the same number of nodes and *p*
# >     * Compare the degree distribution to a *scale-free* network with the same number of nodes.
# > * Who is the top connected character in BotW? (Report results for the undirected network, in-degrees and out-degrees). Comment on your findings. Is this what you would have expected?
# > * Who are the top 5 most connected allies (again in terms of all edges, and in/out-degree)?
# > * Who are the top 5 most connected enemies -- bosses included -- (again in terms of all edges in/out-degree)?

# %% [markdown]
# > The total degree distribution (in + out degree) for you network should resemble the distribution displayed on the image below *(`Isolated` means that we have discarded the nodes with zero degrees)*:
# ![img](https://github.com/SocialComplexityLab/socialgraphs2021/blob/main/files/week4_degrees.png?raw=true)
# > *Tip:* If you want your `matplotlib` plots to look like the one above, you can download the `seaborn` package and do the following: `import seaborn as sns
# sns.set()`

# %%
# Number of nodes and links
print(f'num nodes: {G.number_of_nodes()}')
print(f'num edges: {G.number_of_edges()}')
# Out:
# num nodes: 570
# num edges: 1589

# %%
# Plot in + out degree distributions
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

deg_list = [y for x,y in G.degree()]
sns.histplot(deg_list,bins=400)
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.title('Histogram of the total degree distribution [isolated]')
plt.show()

out_nodes = [x for x,y in G.edges]
out_deg = [out_nodes.count(i) for i in np.unique(G.edges)]

in_nodes = [y for x,y in G.edges]
in_deg = [in_nodes.count(i) for i in np.unique(G.edges)]

sns.histplot(out_deg,bins=400)
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.title('Histogram of the out degree distribution [isolated]')
plt.show()

sns.histplot(in_deg,bins=400)
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.title('Histogram of the in degree distribution [isolated]')
plt.show()

# %%
# find the most connected node
print(max(G.degree(), key=lambda x: x[1]))
# Out:
# ('Link', 379)

# %% [markdown]
# # Week 5 ---------------------------------------------------------------------------------------

# %% [markdown]
# We will continue to work with the network from last week, see the lecture for [Week 4](https://nbviewer.jupyter.org/github/socialcomplexitylab/socialgraphs2021/blob/main/lectures/Week4.ipynb) for details. This is important! Actually, in order to continue with the lecture, you *need* to complete Week 4.
#
# **Important:** To help you with this task and to make sure you have downloaded all characters pages, I have put together the list of characters and their attributes in a [csv file](https://github.com/SocialComplexityLab/socialgraphs2021/blob/main/files/ZeldaBotW_nodes_w_attributes_enriched.csv). Use this file to add nodes with attributes to your network and make sure to find all descriptions and links from the [Zelda Wiki](https://zelda.fandom.com/wiki/Main_Page)!
#
# *Exercise 1:* Build the right graph for visualization:
#
# >1. Use NetworkX `DiGraph` to store the network of characters. Remember that characters are linked if they have a corresponding link between their Zelda Wiki contents.
# >   * **Additionally**, extract the largest component - it will make our work with visualizations much easier (note: removing *isolated* nodes (with no links) does not guarantee that you are left with the largest component).
# >     - *Note 1*: You probably have the right graph if you have more than 500 nodes and more than 1500 edges.
# >     - *Note 2*: For directed graphs use `weakly connected component` to extract the largest component.
# >     - *Note 3*: Further analysis is done with the largest component
# >2. As you build the graph, store the attributes of the nodes (remember the `role`,`race`, and `gender`). On top of that, let's also store the `length of the content` as one of the attributes of the node (i.e. count the number of *words* you have in each character's page). By storing this information as nodal features, we keep all the relevant data in one place. The safe way to count words without counting symbols is to use `regex`, but simpler methods are OK.

# %%
# Get the race and gender attributes from Anna's csv file
path_acsv = 'C:/Users/Nikolaj/OneDrive - Danmarks Tekniske Universitet/DTU/Kandidat/3. semester/Social Graphs and Interactions/socialgraphs2021/files/ZeldaBotW_nodes_w_attributes_enriched.csv'
df_a = pd.read_csv(path_acsv)
display(df_a)
print(df_a[df_a.Name == 'Granté'])

# Get new order of characters from Anna's csv file
characters_a = list(df_a.Name.values)
characters_a = [char.replace(" ","_") for char in characters_a]

# add a column with the word count of each character page
df_a['Word_count'] = [len(re.findall(r'\w+',open(path+word+".txt","r").read())) if word != 'Granté' else 0 for word in characters_a]
display(df_a)

# Create Digraph with attributes
import networkx as nx
G = nx.DiGraph()
nodes_with_attributes = [(df_a.Name[i],{'Role':df_a.Role[i],'Race':df_a.Race[i],'Gender':df_a.Gender[i],'Word_count':df_a.Word_count[i]}) for i in df_a.index]
G.add_nodes_from(nodes_with_attributes)
G.add_edges_from([(x,i) for x in list_dict for i in list_dict[x]])
print(f'num nodes: {G.number_of_nodes()}')
print(f'num edges: {G.number_of_edges()}')
# Out:
#                   Name  Role     Race   Gender
# 0               Baddek  Ally   Hylian     Male
# 1               Bamboo  Ally    Horse  Unknown
# 2                Banji  Ally   Hylian   Female
# 3               Baumar  Ally   Hylian     Male
# 4                Bayge  Ally    Goron     Male
# ..                 ...   ...      ...      ...
# 651  Waterblight Ganon  Boss  Unknown  Unknown
# 652       Master Kohga  Boss  Sheikah     Male
# 653    Monk Maz Koshia  Boss  Sheikah     Male
# 654     Calamity Ganon  Boss   Gerudo     Male
# 655   Dark Beast Ganon  Boss   Gerudo     Male
#
# [656 rows x 4 columns]
#       Name  Role    Race Gender
# 82  Granté  Ally  Hylian   Male
#                   Name  Role     Race   Gender  Word_count
# 0               Baddek  Ally   Hylian     Male        1619
# 1               Bamboo  Ally    Horse  Unknown         276
# 2                Banji  Ally   Hylian   Female        1006
# 3               Baumar  Ally   Hylian     Male         976
# 4                Bayge  Ally    Goron     Male        1254
# ..                 ...   ...      ...      ...         ...
# 651  Waterblight Ganon  Boss  Unknown  Unknown         968
# 652       Master Kohga  Boss  Sheikah     Male        1633
# 653    Monk Maz Koshia  Boss  Sheikah     Male        2017
# 654     Calamity Ganon  Boss   Gerudo     Male        2153
# 655   Dark Beast Ganon  Boss   Gerudo     Male        1540
#
# [656 rows x 5 columns]
# num nodes: 656
# num edges: 1589

# %%
# Remove isolated nodes from the network
G.remove_nodes_from(list(nx.isolates(G)))
print(f'num nodes after removing isolates: {G.number_of_nodes()}')
print(f'num edges after removing isolates: {G.number_of_edges()}')
# Extract the largest component LC
LC = max(nx.weakly_connected_components(G),key=len)
#print(LC)
# Out:
# num nodes after removing isolates: 570
# num edges after removing isolates: 1589

# %% [markdown]
# *Exercise 2:* Let's build a simple visualization of the network
# >1. For the sake of the visualisation, let's convert our network to *undirected graph* (tip: There is a NetworkX command to help you).
# >   * *Note*: Keep the directed graph, we will use it in couple of the following exercises
# >2. Use the NetworkX command `nx.draw_kamada_kawai` to draw the resulting undirected network. (You can find [background on the algorithm here](https://en.wikipedia.org/wiki/Force-directed_graph_drawing).)
# >   * Node color should depend on the `role` attribute (i.e. use different colors for allies, enemies, and bosses)
# >   * Set up your plot so that node-size depends on the node *degree*
# >   * **Optional**: Set up you plot so that edge color depends on the `role` attribute. If an edge connects allies assign `color_a`, if the edge connects enemies/bosses assign `color_b`, in other cases assign `color_c` (i.e. when allies connect to either enemies or bosses). (Here, you get to decide on the colors.)

# %%
# convert Digraph to undirected graph
G_u = G.to_undirected()

# %%
# Plot the undirected graph with different colors for each role, and different sizes of nodes depending on degree

d = dict(G_u.degree)

color_choice = {'Ally':'r','Enemy':'b','Boss':'g'}
colors = [color_choice[x] for x in nx.get_node_attributes(G_u,'Role').values()]


fig,ax = plt.subplots(1,figsize=(14,12))
nx.draw_kamada_kawai(G_u, node_color=colors ,nodelist=d.keys(), node_size=[v*2 for v in d.values()],ax=ax,width=0.5)

# %% [markdown]
# *Exercise 3:* From the previous plot it is more difficult to observe any specific structure in the network. We can make even better visualisations with `ForceAtlas2` package:
# >1. [Force Atlas 2 algorithm](https://github.com/bhargavchippada/forceatlas2) helps to determine the positions of the nodes (see what the result looks like below).
# >2.You can install the  package typing `pip install fa2` in the terminal. The [github page](https://github.com/bhargavchippada/forceatlas2) explains how to use the package to get coordinates for each node.
# >   * (**Hint**: if you install force atlas and Python can't find the package it might be because you computer tries to use the system's `pip`, therefore, try installing using the Anaconda pip explicitly ( on mac you would use `~/anaconda2/bin/pip install fa2`).
# > * Visualize the network using the [Networkx draw function](https://networkx.github.io/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw.html#networkx.drawing.nx_pylab.draw), and node-coordinates from the force atlas algorithm. As in the previous Exercise:
# >   * Node color should depend on the `role` attribute (i.e. use different colors for allies, enemies, and bosses)
# >   * Node size should depend on the node *degree*
# >   * **Optional**: edge color should depend on the `role` attribute. If an edge connects allies assign `color_a`, if the edge connects enemies/bosses assign `color_b`, in other cases assign `color_c` (i.e. when allies connect to either enemies or bosses).
# > * Play with the force atlas algorithm parameters to obtain a visualization you like. It may look similar to the one below (but not necessarily).
# > * Describe the structure you observe. Can you identify nodes with a privileged position in the network? Do you observe chains of connected nodes? Do you see any interesting group of nodes (can you guess who's involved)?
# >   * **Optional**: try to color nodes on the basis of Gender or Race and compare these plots with the previous one. Can you further characterize the structures you've observed? Do you observe new ones?
#
# ![Network](https://github.com/SocialComplexityLab/socialgraphs2021/blob/main/files/Network_fa2.png?raw=true)

# %%
# !pip install fa2
# Out:
# Collecting fa2
#   Downloading fa2-0.3.5-cp37-cp37m-win_amd64.whl (151 kB)
# Requirement already satisfied: tqdm in c:\users\nikolaj\anaconda3\lib\site-packages (from fa2) (4.59.0)
# Requirement already satisfied: scipy in c:\users\nikolaj\anaconda3\lib\site-packages (from fa2) (1.6.2)
# Requirement already satisfied: numpy in c:\users\nikolaj\anaconda3\lib\site-packages (from fa2) (1.19.2)
# Installing collected packages: fa2
# Successfully installed fa2-0.3.5

# %% [markdown]
# *Exercise 4*: We continue with a qualitative inspection of the Zelda Wiki pages, that will help us to intepret our results. We investigate the reasons for links between characters to exist on Zelda Wiki.
#
# >1. Consider the top 3 nodes with highest in-degree in the network. Open the corresponding Zelda Wiki page.
# >   * Consider the set of neighbours pointing towards the node found above. Look for them in the page.
# >   * What is the relation between the characters you identified and his/her network neighbours? (e.g., do they have the same role, are they opponents). You don't need to come up with a grand theory of BotW here, I just want you to think about how links come about.
# >   * Repeat the exercise for the top 3 out-degree node.
# >   * Are there differences between reasons for out- and in-links? Again, there's no right answer here. I just want you to think about some of the reasons why links may occur between characters.
# >2. Are there any nodes with high out-degree and with few incoming connections? If yes, open the Zelda Wiki pages of such characters and explain what happens?
# >3. Are there any nodes with high in-degree and few outcoming connections? Again, open Zelda Wiki pages of such characters and explain what happens?
# >4. From the plot of the network (in *Exercise 3*), we can see that 2 nodes with highest degrees (other than Link) have many common neighbors.
#     * Can you identify who these characters are? Are they opponents? How many common neighbors do they have?
#     * Can you characterize the common neighbors in terms of their Gender and Race? What about their Zelda Wiki pages (do they have a specific role in the BotW story)?

# %% [markdown]
# ### 1.

# %%
# Extract the top 3 nodes with highest in-degree in the network
top3in_deg = sorted(G.in_degree(),key=lambda x: x[1],reverse=True)[:3]
print(top3in_deg)
# Extract the wiki pages (txt files) from these top 3 and save in a list
top3in_wiki = [open(path+word[0].replace(" ","_")+".txt","r").read() for word in top3in_deg]
# Out:
# [('Link', 378), ('Calamity Ganon', 97), ('Hylia', 67)]

# %%
# https://zelda.fandom.com/wiki/Link - Main character, Hero. Is controlled by the goddess Hylia
# https://zelda.fandom.com/wiki/Calamity_Ganon - Biggest boss/enemy. Great King of Evil, enemy of Hylia
# https://zelda.fandom.com/wiki/Hylia - Goddess, she influences the world

# %%
# Get the list of neighbours for each of the top 3 in-deg nodes
[list(G.neighbors(top3in_deg[0][0])),list(G.neighbors(top3in_deg[1][0])),list(G.neighbors(top3in_deg[2][0]))]
# Out:
# [['Stalnox'],
#  ['Link', 'Princess Zelda', 'Calamity Ganon'],
#  ['Bokoblin',
#   'Link',
#   'King Rhoam',
#   'Purah',
#   'Princess Zelda',
#   'Paya',
#   'Hylia',
#   'Fire Wizzrobe',
#   'Calamity Ganon']]

# %%
# Extract the top 3 nodes with highest out-degree in the network
top3out_deg = sorted(G.out_degree(),key=lambda x: x[1],reverse=True)[:3]
print(top3out_deg)
# Extract the wiki pages (txt files) from these top 3 and save in a list
top3out_wiki = [open(path+word[0].replace(" ","_")+".txt","r").read() for word in top3out_deg]

# Get the list of neighbours for each of the top 3 out-deg nodes
[list(G.neighbors(top3out_deg[0][0])),list(G.neighbors(top3out_deg[1][0])),list(G.neighbors(top3out_deg[2][0]))]
# Out:
# [('Tray', 14), ('Snow Octorok', 12), ('Keese', 11)]
# [['Link',
#   'Muava',
#   'King Rhoam',
#   'Riju',
#   'Strade',
#   'Ploka',
#   'Farosh',
#   'Naydra',
#   'Lyndae',
#   'Princess Zelda',
#   'Molduking',
#   'Ashai',
#   'Molduga',
#   'Dinraal'],
#  ['Lizalfos',
#   'Golden Lizalfos',
#   'Link',
#   'Black Lizalfos',
#   'Silver Lizalfos',
#   'Electric Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Cursed Lizalfos',
#   'Stalkoblin',
#   'Stalmoblin',
#   'Blue Lizalfos'],
#  ['Golden Lizalfos',
#   'Link',
#   'Black Lizalfos',
#   'Silver Lizalfos',
#   'Electric Lizalfos',
#   'Fire-Breath Lizalfos',
#   'Ice-Breath Lizalfos',
#   'Cursed Lizalfos',
#   'Moblin',
#   'Blue Lizalfos',
#   'Stalizalfos']]

# %%
# https://zelda.fandom.com/wiki/Tray
# https://zelda.fandom.com/wiki/Snow_Octorok
# https://zelda.fandom.com/wiki/Keese

# %% [markdown]
# ### 2.

# %%
#...
